# %%
import os
import random
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output

# %%
def read_decimal_file(file_path):
    """
    Reads a .txt file containing one decimal number per line and returns a list of floats.

    Parameters:
    - file_path (str): Path to the .txt file.

    Returns:
    - list: A list of decimal numbers as floats.
    """
    try:
        with open(file_path, 'r') as file:
            # Read lines, strip whitespace, and convert to float
            data = [float(line.strip()) for line in file if line.strip()]
        return data
    except Exception as e:
        print(f"Error reading file: {e}")
        return []

# %%
def process_normalization_TSP_data(data, num_city, file_path, pop_size=100):
    """
    Process the normalization data by creating ranked sets and save them to a file.

    Parameters:
    - data (list or numpy array): The input data.
    - num_city (int): Number of cities in each set.
    - pop_size (int): Population size (number of sets).
    - file_path (str): Path to save the ranked sets.

    Returns:
    - list: A list of ranked sets.
    """
    total_numbers_needed = num_city * pop_size
    data_len = len(data)

    # Ensure the data has enough numbers to wrap around
    if data_len < num_city:
        raise ValueError(f"Not enough data points. The data must be at least {num_city} long.")

    # Randomly choose a starting position
    start_position = np.random.randint(0, data_len)

    # Extract the required subset of data with wrapping
    selected_data = []
    for i in range(total_numbers_needed):
        selected_data.append(data[(start_position + i) % data_len])

    # Split the data into `pop_size` sets, each with `num_city` numbers
    sets = np.array(selected_data).reshape(pop_size, num_city)

    # Rank each number in each set (0 to num_city-1)
    ranked_sets = []
    for s in sets:
        ranked = np.argsort(np.argsort(s))  # Rank the numbers in the set
        ranked_sets.append(ranked.tolist())

    # Save the ranked sets to the specified file path
    with open(file_path, 'w') as file:
        for ranked_set in ranked_sets:
            file.write(" ".join(map(str, ranked_set)) + "\n")

    print(f"Ranked sets saved to {file_path}")
    return start_position

# %%
filePath1 = os.path.join("normalized","beam_splitter_number_stream_normalized.txt")
filePath2 = os.path.join("normalized","ibm_com_number_stream_normalized.txt")
filePath3 = os.path.join("normalized","MT19937_number_stream_normalized.txt")
filePath4 = os.path.join("normalized","quasirandom_number_stream_normalized.txt")

# %%
BeamSplitter = read_decimal_file(filePath1)
Ibm = read_decimal_file(filePath2)
Mt19937 = read_decimal_file(filePath3)
QuasiRandom = read_decimal_file(filePath4)

# %%
# Number of repetitions
num_trials = 30

# %% [markdown]
# # <span style="color:blue; font-weight:bold;">TSP init</span>

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">berlin52.tsp</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Berlin52"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = BeamSplitter, num_city = 52, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_11\BeamSplitter.txt
# 20408615
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_12\BeamSplitter.txt
# 69876314
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_13\BeamSplitter.txt
# 28978043
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_14\BeamSplitter.txt
# 60325811
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_15\BeamSplitter.txt
# 537917
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_16\BeamSplitter.txt
# 7143123
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_17\BeamSplitter.txt
# 24771390
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_18\BeamSplitter.txt
# 30985769
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_19\BeamSplitter.txt
# 5378749
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_20\BeamSplitter.txt
# 680003
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_21\BeamSplitter.txt
# 22471980
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_22\BeamSplitter.txt
# 26610246
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_23\BeamSplitter.txt
# 72521513
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_24\BeamSplitter.txt
# 37256019
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_25\BeamSplitter.txt
# 80057747
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_26\BeamSplitter.txt
# 62178660
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_27\BeamSplitter.txt
# 39626842
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_28\BeamSplitter.txt
# 42596158
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_29\BeamSplitter.txt
# 34442158
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_30\BeamSplitter.txt
# 51698664

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Berlin52"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Ibm, num_city = 52, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_11\Ibm.txt
# 37217111
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_12\Ibm.txt
# 69577639
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_13\Ibm.txt
# 59610186
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_14\Ibm.txt
# 18726512
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_15\Ibm.txt
# 66178221
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_16\Ibm.txt
# 76557677
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_17\Ibm.txt
# 21153419
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_18\Ibm.txt
# 13952745
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_19\Ibm.txt
# 29960402
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_20\Ibm.txt
# 34614423
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_21\Ibm.txt
# 54496904
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_22\Ibm.txt
# 36828312
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_23\Ibm.txt
# 35007527
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_24\Ibm.txt
# 5620562
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_25\Ibm.txt
# 75255593
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_26\Ibm.txt
# 47174611
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_27\Ibm.txt
# 77371430
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_28\Ibm.txt
# 43549987
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_29\Ibm.txt
# 17047439
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_30\Ibm.txt
# 32053059

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Berlin52"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = QuasiRandom, num_city = 52, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_11\QuasiRandom.txt
# 44034931
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_12\QuasiRandom.txt
# 8598118
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_13\QuasiRandom.txt
# 53269317
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_14\QuasiRandom.txt
# 40880959
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_15\QuasiRandom.txt
# 37213444
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_16\QuasiRandom.txt
# 75229034
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_17\QuasiRandom.txt
# 19187154
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_18\QuasiRandom.txt
# 74185665
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_19\QuasiRandom.txt
# 81627515
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_20\QuasiRandom.txt
# 55045583
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_21\QuasiRandom.txt
# 59447840
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_22\QuasiRandom.txt
# 79839250
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_23\QuasiRandom.txt
# 69339724
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_24\QuasiRandom.txt
# 62158767
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_25\QuasiRandom.txt
# 4503323
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_26\QuasiRandom.txt
# 73068445
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_27\QuasiRandom.txt
# 10426426
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_28\QuasiRandom.txt
# 8990311
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_29\QuasiRandom.txt
# 12983045
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_30\QuasiRandom.txt
# 35200186

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Berlin52"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Mt19937, num_city = 52, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_11\Mt19937.txt
# 71056656
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_12\Mt19937.txt
# 67656471
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_13\Mt19937.txt
# 34335290
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_14\Mt19937.txt
# 64093830
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_15\Mt19937.txt
# 15936853
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_16\Mt19937.txt
# 4823348
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_17\Mt19937.txt
# 2454843
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_18\Mt19937.txt
# 18115937
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_19\Mt19937.txt
# 18924865
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_20\Mt19937.txt
# 48019890
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_21\Mt19937.txt
# 9629580
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_22\Mt19937.txt
# 50796086
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_23\Mt19937.txt
# 73238381
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_24\Mt19937.txt
# 71256814
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_25\Mt19937.txt
# 67689690
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_26\Mt19937.txt
# 39469414
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_27\Mt19937.txt
# 37868714
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_28\Mt19937.txt
# 4143875
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_29\Mt19937.txt
# 38916525
# Ranked sets saved to starting_solution\TSP\Berlin52\trial_30\Mt19937.txt
# 13709259

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">Bier127.tsp</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Bier127"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = BeamSplitter, num_city = 127, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Bier127\trial_11\BeamSplitter.txt
# 57419753
# Ranked sets saved to starting_solution\TSP\Bier127\trial_12\BeamSplitter.txt
# 21708420
# Ranked sets saved to starting_solution\TSP\Bier127\trial_13\BeamSplitter.txt
# 50549024
# Ranked sets saved to starting_solution\TSP\Bier127\trial_14\BeamSplitter.txt
# 38311880
# Ranked sets saved to starting_solution\TSP\Bier127\trial_15\BeamSplitter.txt
# 79667566
# Ranked sets saved to starting_solution\TSP\Bier127\trial_16\BeamSplitter.txt
# 81532051
# Ranked sets saved to starting_solution\TSP\Bier127\trial_17\BeamSplitter.txt
# 8799264
# Ranked sets saved to starting_solution\TSP\Bier127\trial_18\BeamSplitter.txt
# 30274722
# Ranked sets saved to starting_solution\TSP\Bier127\trial_19\BeamSplitter.txt
# 68455430
# Ranked sets saved to starting_solution\TSP\Bier127\trial_20\BeamSplitter.txt
# 57164895
# Ranked sets saved to starting_solution\TSP\Bier127\trial_21\BeamSplitter.txt
# 1190042
# Ranked sets saved to starting_solution\TSP\Bier127\trial_22\BeamSplitter.txt
# 62595941
# Ranked sets saved to starting_solution\TSP\Bier127\trial_23\BeamSplitter.txt
# 65693324
# Ranked sets saved to starting_solution\TSP\Bier127\trial_24\BeamSplitter.txt
# 42890854
# Ranked sets saved to starting_solution\TSP\Bier127\trial_25\BeamSplitter.txt
# 42428992
# Ranked sets saved to starting_solution\TSP\Bier127\trial_26\BeamSplitter.txt
# 25651956
# Ranked sets saved to starting_solution\TSP\Bier127\trial_27\BeamSplitter.txt
# 35626362
# Ranked sets saved to starting_solution\TSP\Bier127\trial_28\BeamSplitter.txt
# 75381386
# Ranked sets saved to starting_solution\TSP\Bier127\trial_29\BeamSplitter.txt
# 80381362
# Ranked sets saved to starting_solution\TSP\Bier127\trial_30\BeamSplitter.txt
# 40525766

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Bier127"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Ibm, num_city = 127, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Bier127\trial_11\Ibm.txt
# 1223488
# Ranked sets saved to starting_solution\TSP\Bier127\trial_12\Ibm.txt
# 23500459
# Ranked sets saved to starting_solution\TSP\Bier127\trial_13\Ibm.txt
# 60501024
# Ranked sets saved to starting_solution\TSP\Bier127\trial_14\Ibm.txt
# 2287123
# Ranked sets saved to starting_solution\TSP\Bier127\trial_15\Ibm.txt
# 2793716
# Ranked sets saved to starting_solution\TSP\Bier127\trial_16\Ibm.txt
# 81607556
# Ranked sets saved to starting_solution\TSP\Bier127\trial_17\Ibm.txt
# 34824270
# Ranked sets saved to starting_solution\TSP\Bier127\trial_18\Ibm.txt
# 39119693
# Ranked sets saved to starting_solution\TSP\Bier127\trial_19\Ibm.txt
# 71260234
# Ranked sets saved to starting_solution\TSP\Bier127\trial_20\Ibm.txt
# 15293780
# Ranked sets saved to starting_solution\TSP\Bier127\trial_21\Ibm.txt
# 14502838
# Ranked sets saved to starting_solution\TSP\Bier127\trial_22\Ibm.txt
# 57806011
# Ranked sets saved to starting_solution\TSP\Bier127\trial_23\Ibm.txt
# 76666416
# Ranked sets saved to starting_solution\TSP\Bier127\trial_24\Ibm.txt
# 63205064
# Ranked sets saved to starting_solution\TSP\Bier127\trial_25\Ibm.txt
# 67708265
# Ranked sets saved to starting_solution\TSP\Bier127\trial_26\Ibm.txt
# 34958537
# Ranked sets saved to starting_solution\TSP\Bier127\trial_27\Ibm.txt
# 61569349
# Ranked sets saved to starting_solution\TSP\Bier127\trial_28\Ibm.txt
# 67355753
# Ranked sets saved to starting_solution\TSP\Bier127\trial_29\Ibm.txt
# 29793794
# Ranked sets saved to starting_solution\TSP\Bier127\trial_30\Ibm.txt
# 59505104

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Bier127"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = QuasiRandom, num_city = 127, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Bier127\trial_11\QuasiRandom.txt
# 22740496
# Ranked sets saved to starting_solution\TSP\Bier127\trial_12\QuasiRandom.txt
# 18995964
# Ranked sets saved to starting_solution\TSP\Bier127\trial_13\QuasiRandom.txt
# 62476530
# Ranked sets saved to starting_solution\TSP\Bier127\trial_14\QuasiRandom.txt
# 17684836
# Ranked sets saved to starting_solution\TSP\Bier127\trial_15\QuasiRandom.txt
# 62861789
# Ranked sets saved to starting_solution\TSP\Bier127\trial_16\QuasiRandom.txt
# 43717857
# Ranked sets saved to starting_solution\TSP\Bier127\trial_17\QuasiRandom.txt
# 19629378
# Ranked sets saved to starting_solution\TSP\Bier127\trial_18\QuasiRandom.txt
# 25421460
# Ranked sets saved to starting_solution\TSP\Bier127\trial_19\QuasiRandom.txt
# 28444241
# Ranked sets saved to starting_solution\TSP\Bier127\trial_20\QuasiRandom.txt
# 15735150
# Ranked sets saved to starting_solution\TSP\Bier127\trial_21\QuasiRandom.txt
# 72536740
# Ranked sets saved to starting_solution\TSP\Bier127\trial_22\QuasiRandom.txt
# 5644385
# Ranked sets saved to starting_solution\TSP\Bier127\trial_23\QuasiRandom.txt
# 14481212
# Ranked sets saved to starting_solution\TSP\Bier127\trial_24\QuasiRandom.txt
# 7986156
# Ranked sets saved to starting_solution\TSP\Bier127\trial_25\QuasiRandom.txt
# 36658552
# Ranked sets saved to starting_solution\TSP\Bier127\trial_26\QuasiRandom.txt
# 18652185
# Ranked sets saved to starting_solution\TSP\Bier127\trial_27\QuasiRandom.txt
# 51479998
# Ranked sets saved to starting_solution\TSP\Bier127\trial_28\QuasiRandom.txt
# 81566756
# Ranked sets saved to starting_solution\TSP\Bier127\trial_29\QuasiRandom.txt
# 25733292
# Ranked sets saved to starting_solution\TSP\Bier127\trial_30\QuasiRandom.txt
# 22434335

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Bier127"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Mt19937, num_city = 127, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Bier127\trial_11\Mt19937.txt
# 49869443
# Ranked sets saved to starting_solution\TSP\Bier127\trial_12\Mt19937.txt
# 53813391
# Ranked sets saved to starting_solution\TSP\Bier127\trial_13\Mt19937.txt
# 78497674
# Ranked sets saved to starting_solution\TSP\Bier127\trial_14\Mt19937.txt
# 68921908
# Ranked sets saved to starting_solution\TSP\Bier127\trial_15\Mt19937.txt
# 79988844
# Ranked sets saved to starting_solution\TSP\Bier127\trial_16\Mt19937.txt
# 18418990
# Ranked sets saved to starting_solution\TSP\Bier127\trial_17\Mt19937.txt
# 11493699
# Ranked sets saved to starting_solution\TSP\Bier127\trial_18\Mt19937.txt
# 64410058
# Ranked sets saved to starting_solution\TSP\Bier127\trial_19\Mt19937.txt
# 78484029
# Ranked sets saved to starting_solution\TSP\Bier127\trial_20\Mt19937.txt
# 16879185
# Ranked sets saved to starting_solution\TSP\Bier127\trial_21\Mt19937.txt
# 8799488
# Ranked sets saved to starting_solution\TSP\Bier127\trial_22\Mt19937.txt
# 39346141
# Ranked sets saved to starting_solution\TSP\Bier127\trial_23\Mt19937.txt
# 61727760
# Ranked sets saved to starting_solution\TSP\Bier127\trial_24\Mt19937.txt
# 60035694
# Ranked sets saved to starting_solution\TSP\Bier127\trial_25\Mt19937.txt
# 52138820
# Ranked sets saved to starting_solution\TSP\Bier127\trial_26\Mt19937.txt
# 77276562
# Ranked sets saved to starting_solution\TSP\Bier127\trial_27\Mt19937.txt
# 35308100
# Ranked sets saved to starting_solution\TSP\Bier127\trial_28\Mt19937.txt
# 59097462
# Ranked sets saved to starting_solution\TSP\Bier127\trial_29\Mt19937.txt
# 78319574
# Ranked sets saved to starting_solution\TSP\Bier127\trial_30\Mt19937.txt
# 16881479

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">Eil101.tsp</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Eil101"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = BeamSplitter, num_city = 101, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Eil101\trial_11\BeamSplitter.txt
# 6828896
# Ranked sets saved to starting_solution\TSP\Eil101\trial_12\BeamSplitter.txt
# 8664316
# Ranked sets saved to starting_solution\TSP\Eil101\trial_13\BeamSplitter.txt
# 46698727
# Ranked sets saved to starting_solution\TSP\Eil101\trial_14\BeamSplitter.txt
# 5164273
# Ranked sets saved to starting_solution\TSP\Eil101\trial_15\BeamSplitter.txt
# 71613284
# Ranked sets saved to starting_solution\TSP\Eil101\trial_16\BeamSplitter.txt
# 78331076
# Ranked sets saved to starting_solution\TSP\Eil101\trial_17\BeamSplitter.txt
# 1204304
# Ranked sets saved to starting_solution\TSP\Eil101\trial_18\BeamSplitter.txt
# 24555106
# Ranked sets saved to starting_solution\TSP\Eil101\trial_19\BeamSplitter.txt
# 74709839
# Ranked sets saved to starting_solution\TSP\Eil101\trial_20\BeamSplitter.txt
# 77318300
# Ranked sets saved to starting_solution\TSP\Eil101\trial_21\BeamSplitter.txt
# 30716322
# Ranked sets saved to starting_solution\TSP\Eil101\trial_22\BeamSplitter.txt
# 41125723
# Ranked sets saved to starting_solution\TSP\Eil101\trial_23\BeamSplitter.txt
# 27722835
# Ranked sets saved to starting_solution\TSP\Eil101\trial_24\BeamSplitter.txt
# 26401011
# Ranked sets saved to starting_solution\TSP\Eil101\trial_25\BeamSplitter.txt
# 76404652
# Ranked sets saved to starting_solution\TSP\Eil101\trial_26\BeamSplitter.txt
# 5230917
# Ranked sets saved to starting_solution\TSP\Eil101\trial_27\BeamSplitter.txt
# 45397626
# Ranked sets saved to starting_solution\TSP\Eil101\trial_28\BeamSplitter.txt
# 63323332
# Ranked sets saved to starting_solution\TSP\Eil101\trial_29\BeamSplitter.txt
# 71105144
# Ranked sets saved to starting_solution\TSP\Eil101\trial_30\BeamSplitter.txt
# 63564011

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Eil101"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Ibm, num_city = 101, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Eil101\trial_11\Ibm.txt
# 16001337
# Ranked sets saved to starting_solution\TSP\Eil101\trial_12\Ibm.txt
# 73198480
# Ranked sets saved to starting_solution\TSP\Eil101\trial_13\Ibm.txt
# 18975796
# Ranked sets saved to starting_solution\TSP\Eil101\trial_14\Ibm.txt
# 21097981
# Ranked sets saved to starting_solution\TSP\Eil101\trial_15\Ibm.txt
# 25460711
# Ranked sets saved to starting_solution\TSP\Eil101\trial_16\Ibm.txt
# 79451351
# Ranked sets saved to starting_solution\TSP\Eil101\trial_17\Ibm.txt
# 29852690
# Ranked sets saved to starting_solution\TSP\Eil101\trial_18\Ibm.txt
# 81018621
# Ranked sets saved to starting_solution\TSP\Eil101\trial_19\Ibm.txt
# 32066564
# Ranked sets saved to starting_solution\TSP\Eil101\trial_20\Ibm.txt
# 47409955
# Ranked sets saved to starting_solution\TSP\Eil101\trial_21\Ibm.txt
# 27535334
# Ranked sets saved to starting_solution\TSP\Eil101\trial_22\Ibm.txt
# 15834249
# Ranked sets saved to starting_solution\TSP\Eil101\trial_23\Ibm.txt
# 7642602
# Ranked sets saved to starting_solution\TSP\Eil101\trial_24\Ibm.txt
# 50610310
# Ranked sets saved to starting_solution\TSP\Eil101\trial_25\Ibm.txt
# 6025711
# Ranked sets saved to starting_solution\TSP\Eil101\trial_26\Ibm.txt
# 24790010
# Ranked sets saved to starting_solution\TSP\Eil101\trial_27\Ibm.txt
# 48836613
# Ranked sets saved to starting_solution\TSP\Eil101\trial_28\Ibm.txt
# 59424152
# Ranked sets saved to starting_solution\TSP\Eil101\trial_29\Ibm.txt
# 62055489
# Ranked sets saved to starting_solution\TSP\Eil101\trial_30\Ibm.txt
# 2193184

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Eil101"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = QuasiRandom, num_city = 101, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Eil101\trial_11\QuasiRandom.txt
# 55146845
# Ranked sets saved to starting_solution\TSP\Eil101\trial_12\QuasiRandom.txt
# 65479358
# Ranked sets saved to starting_solution\TSP\Eil101\trial_13\QuasiRandom.txt
# 30593825
# Ranked sets saved to starting_solution\TSP\Eil101\trial_14\QuasiRandom.txt
# 45444734
# Ranked sets saved to starting_solution\TSP\Eil101\trial_15\QuasiRandom.txt
# 82157378
# Ranked sets saved to starting_solution\TSP\Eil101\trial_16\QuasiRandom.txt
# 55962411
# Ranked sets saved to starting_solution\TSP\Eil101\trial_17\QuasiRandom.txt
# 50094767
# Ranked sets saved to starting_solution\TSP\Eil101\trial_18\QuasiRandom.txt
# 17962255
# Ranked sets saved to starting_solution\TSP\Eil101\trial_19\QuasiRandom.txt
# 70134065
# Ranked sets saved to starting_solution\TSP\Eil101\trial_20\QuasiRandom.txt
# 32057147
# Ranked sets saved to starting_solution\TSP\Eil101\trial_21\QuasiRandom.txt
# 27121164
# Ranked sets saved to starting_solution\TSP\Eil101\trial_22\QuasiRandom.txt
# 48293560
# Ranked sets saved to starting_solution\TSP\Eil101\trial_23\QuasiRandom.txt
# 64213697
# Ranked sets saved to starting_solution\TSP\Eil101\trial_24\QuasiRandom.txt
# 44895508
# Ranked sets saved to starting_solution\TSP\Eil101\trial_25\QuasiRandom.txt
# 68222943
# Ranked sets saved to starting_solution\TSP\Eil101\trial_26\QuasiRandom.txt
# 8244628
# Ranked sets saved to starting_solution\TSP\Eil101\trial_27\QuasiRandom.txt
# 79148289
# Ranked sets saved to starting_solution\TSP\Eil101\trial_28\QuasiRandom.txt
# 18052762
# Ranked sets saved to starting_solution\TSP\Eil101\trial_29\QuasiRandom.txt
# 44598184
# Ranked sets saved to starting_solution\TSP\Eil101\trial_30\QuasiRandom.txt
# 81747941

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Eil101"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Mt19937, num_city = 101, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Eil101\trial_11\Mt19937.txt
# 49140465
# Ranked sets saved to starting_solution\TSP\Eil101\trial_12\Mt19937.txt
# 57552776
# Ranked sets saved to starting_solution\TSP\Eil101\trial_13\Mt19937.txt
# 78769675
# Ranked sets saved to starting_solution\TSP\Eil101\trial_14\Mt19937.txt
# 38877716
# Ranked sets saved to starting_solution\TSP\Eil101\trial_15\Mt19937.txt
# 42324415
# Ranked sets saved to starting_solution\TSP\Eil101\trial_16\Mt19937.txt
# 80789880
# Ranked sets saved to starting_solution\TSP\Eil101\trial_17\Mt19937.txt
# 78812289
# Ranked sets saved to starting_solution\TSP\Eil101\trial_18\Mt19937.txt
# 11117024
# Ranked sets saved to starting_solution\TSP\Eil101\trial_19\Mt19937.txt
# 30537137
# Ranked sets saved to starting_solution\TSP\Eil101\trial_20\Mt19937.txt
# 12221384
# Ranked sets saved to starting_solution\TSP\Eil101\trial_21\Mt19937.txt
# 31419018
# Ranked sets saved to starting_solution\TSP\Eil101\trial_22\Mt19937.txt
# 24552252
# Ranked sets saved to starting_solution\TSP\Eil101\trial_23\Mt19937.txt
# 1040902
# Ranked sets saved to starting_solution\TSP\Eil101\trial_24\Mt19937.txt
# 24705758
# Ranked sets saved to starting_solution\TSP\Eil101\trial_25\Mt19937.txt
# 63965034
# Ranked sets saved to starting_solution\TSP\Eil101\trial_26\Mt19937.txt
# 15974652
# Ranked sets saved to starting_solution\TSP\Eil101\trial_27\Mt19937.txt
# 72455838
# Ranked sets saved to starting_solution\TSP\Eil101\trial_28\Mt19937.txt
# 58664817
# Ranked sets saved to starting_solution\TSP\Eil101\trial_29\Mt19937.txt
# 8468929
# Ranked sets saved to starting_solution\TSP\Eil101\trial_30\Mt19937.txt
# 47844641

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">Pr76.tsp</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Pr76"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = BeamSplitter, num_city = 76, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Pr76\trial_11\BeamSplitter.txt
# 75470843
# Ranked sets saved to starting_solution\TSP\Pr76\trial_12\BeamSplitter.txt
# 23009450
# Ranked sets saved to starting_solution\TSP\Pr76\trial_13\BeamSplitter.txt
# 7230780
# Ranked sets saved to starting_solution\TSP\Pr76\trial_14\BeamSplitter.txt
# 40367860
# Ranked sets saved to starting_solution\TSP\Pr76\trial_15\BeamSplitter.txt
# 76765096
# Ranked sets saved to starting_solution\TSP\Pr76\trial_16\BeamSplitter.txt
# 47215611
# Ranked sets saved to starting_solution\TSP\Pr76\trial_17\BeamSplitter.txt
# 24405794
# Ranked sets saved to starting_solution\TSP\Pr76\trial_18\BeamSplitter.txt
# 55318960
# Ranked sets saved to starting_solution\TSP\Pr76\trial_19\BeamSplitter.txt
# 80627021
# Ranked sets saved to starting_solution\TSP\Pr76\trial_20\BeamSplitter.txt
# 46439235
# Ranked sets saved to starting_solution\TSP\Pr76\trial_21\BeamSplitter.txt
# 34514382
# Ranked sets saved to starting_solution\TSP\Pr76\trial_22\BeamSplitter.txt
# 81717235
# Ranked sets saved to starting_solution\TSP\Pr76\trial_23\BeamSplitter.txt
# 826604
# Ranked sets saved to starting_solution\TSP\Pr76\trial_24\BeamSplitter.txt
# 58416282
# Ranked sets saved to starting_solution\TSP\Pr76\trial_25\BeamSplitter.txt
# 78404661
# Ranked sets saved to starting_solution\TSP\Pr76\trial_26\BeamSplitter.txt
# 38733789
# Ranked sets saved to starting_solution\TSP\Pr76\trial_27\BeamSplitter.txt
# 17611153
# Ranked sets saved to starting_solution\TSP\Pr76\trial_28\BeamSplitter.txt
# 27690819
# Ranked sets saved to starting_solution\TSP\Pr76\trial_29\BeamSplitter.txt
# 3798117
# Ranked sets saved to starting_solution\TSP\Pr76\trial_30\BeamSplitter.txt
# 15342698

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Pr76"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Ibm, num_city = 76, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Pr76\trial_11\Ibm.txt
# 81143401
# Ranked sets saved to starting_solution\TSP\Pr76\trial_12\Ibm.txt
# 44047765
# Ranked sets saved to starting_solution\TSP\Pr76\trial_13\Ibm.txt
# 46076002
# Ranked sets saved to starting_solution\TSP\Pr76\trial_14\Ibm.txt
# 79730127
# Ranked sets saved to starting_solution\TSP\Pr76\trial_15\Ibm.txt
# 28037045
# Ranked sets saved to starting_solution\TSP\Pr76\trial_16\Ibm.txt
# 53921780
# Ranked sets saved to starting_solution\TSP\Pr76\trial_17\Ibm.txt
# 12689015
# Ranked sets saved to starting_solution\TSP\Pr76\trial_18\Ibm.txt
# 15796326
# Ranked sets saved to starting_solution\TSP\Pr76\trial_19\Ibm.txt
# 78366259
# Ranked sets saved to starting_solution\TSP\Pr76\trial_20\Ibm.txt
# 11567736
# Ranked sets saved to starting_solution\TSP\Pr76\trial_21\Ibm.txt
# 24855551
# Ranked sets saved to starting_solution\TSP\Pr76\trial_22\Ibm.txt
# 2139212
# Ranked sets saved to starting_solution\TSP\Pr76\trial_23\Ibm.txt
# 13307797
# Ranked sets saved to starting_solution\TSP\Pr76\trial_24\Ibm.txt
# 9521152
# Ranked sets saved to starting_solution\TSP\Pr76\trial_25\Ibm.txt
# 14470616
# Ranked sets saved to starting_solution\TSP\Pr76\trial_26\Ibm.txt
# 77139769
# Ranked sets saved to starting_solution\TSP\Pr76\trial_27\Ibm.txt
# 55227473
# Ranked sets saved to starting_solution\TSP\Pr76\trial_28\Ibm.txt
# 43380166
# Ranked sets saved to starting_solution\TSP\Pr76\trial_29\Ibm.txt
# 69683351
# Ranked sets saved to starting_solution\TSP\Pr76\trial_30\Ibm.txt
# 68201231

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Pr76"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = QuasiRandom, num_city = 76, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Pr76\trial_11\QuasiRandom.txt
# 10334766
# Ranked sets saved to starting_solution\TSP\Pr76\trial_12\QuasiRandom.txt
# 10189118
# Ranked sets saved to starting_solution\TSP\Pr76\trial_13\QuasiRandom.txt
# 66052646
# Ranked sets saved to starting_solution\TSP\Pr76\trial_14\QuasiRandom.txt
# 54835165
# Ranked sets saved to starting_solution\TSP\Pr76\trial_15\QuasiRandom.txt
# 45097757
# Ranked sets saved to starting_solution\TSP\Pr76\trial_16\QuasiRandom.txt
# 1347444
# Ranked sets saved to starting_solution\TSP\Pr76\trial_17\QuasiRandom.txt
# 24053908
# Ranked sets saved to starting_solution\TSP\Pr76\trial_18\QuasiRandom.txt
# 69168411
# Ranked sets saved to starting_solution\TSP\Pr76\trial_19\QuasiRandom.txt
# 37091780
# Ranked sets saved to starting_solution\TSP\Pr76\trial_20\QuasiRandom.txt
# 68482295
# Ranked sets saved to starting_solution\TSP\Pr76\trial_21\QuasiRandom.txt
# 42942641
# Ranked sets saved to starting_solution\TSP\Pr76\trial_22\QuasiRandom.txt
# 45482235
# Ranked sets saved to starting_solution\TSP\Pr76\trial_23\QuasiRandom.txt
# 20402091
# Ranked sets saved to starting_solution\TSP\Pr76\trial_24\QuasiRandom.txt
# 9092824
# Ranked sets saved to starting_solution\TSP\Pr76\trial_25\QuasiRandom.txt
# 46383956
# Ranked sets saved to starting_solution\TSP\Pr76\trial_26\QuasiRandom.txt
# 46164195
# Ranked sets saved to starting_solution\TSP\Pr76\trial_27\QuasiRandom.txt
# 4630636
# Ranked sets saved to starting_solution\TSP\Pr76\trial_28\QuasiRandom.txt
# 19476328
# Ranked sets saved to starting_solution\TSP\Pr76\trial_29\QuasiRandom.txt
# 66581079
# Ranked sets saved to starting_solution\TSP\Pr76\trial_30\QuasiRandom.txt
# 25851473

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\Pr76"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Mt19937, num_city = 76, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\Pr76\trial_11\Mt19937.txt
# 43453034
# Ranked sets saved to starting_solution\TSP\Pr76\trial_12\Mt19937.txt
# 4243076
# Ranked sets saved to starting_solution\TSP\Pr76\trial_13\Mt19937.txt
# 63046372
# Ranked sets saved to starting_solution\TSP\Pr76\trial_14\Mt19937.txt
# 32858521
# Ranked sets saved to starting_solution\TSP\Pr76\trial_15\Mt19937.txt
# 47133772
# Ranked sets saved to starting_solution\TSP\Pr76\trial_16\Mt19937.txt
# 61743212
# Ranked sets saved to starting_solution\TSP\Pr76\trial_17\Mt19937.txt
# 64686233
# Ranked sets saved to starting_solution\TSP\Pr76\trial_18\Mt19937.txt
# 40679465
# Ranked sets saved to starting_solution\TSP\Pr76\trial_19\Mt19937.txt
# 80867818
# Ranked sets saved to starting_solution\TSP\Pr76\trial_20\Mt19937.txt
# 47451401
# Ranked sets saved to starting_solution\TSP\Pr76\trial_21\Mt19937.txt
# 45575208
# Ranked sets saved to starting_solution\TSP\Pr76\trial_22\Mt19937.txt
# 26620594
# Ranked sets saved to starting_solution\TSP\Pr76\trial_23\Mt19937.txt
# 25975488
# Ranked sets saved to starting_solution\TSP\Pr76\trial_24\Mt19937.txt
# 27758355
# Ranked sets saved to starting_solution\TSP\Pr76\trial_25\Mt19937.txt
# 71203052
# Ranked sets saved to starting_solution\TSP\Pr76\trial_26\Mt19937.txt
# 72652499
# Ranked sets saved to starting_solution\TSP\Pr76\trial_27\Mt19937.txt
# 64145478
# Ranked sets saved to starting_solution\TSP\Pr76\trial_28\Mt19937.txt
# 60304390
# Ranked sets saved to starting_solution\TSP\Pr76\trial_29\Mt19937.txt
# 9623727
# Ranked sets saved to starting_solution\TSP\Pr76\trial_30\Mt19937.txt
# 38166100

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">St70.tsp</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\St70"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = BeamSplitter, num_city = 70, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\St70\trial_11\BeamSplitter.txt
# 28130795
# Ranked sets saved to starting_solution\TSP\St70\trial_12\BeamSplitter.txt
# 57311277
# Ranked sets saved to starting_solution\TSP\St70\trial_13\BeamSplitter.txt
# 41847046
# Ranked sets saved to starting_solution\TSP\St70\trial_14\BeamSplitter.txt
# 20964667
# Ranked sets saved to starting_solution\TSP\St70\trial_15\BeamSplitter.txt
# 19806003
# Ranked sets saved to starting_solution\TSP\St70\trial_16\BeamSplitter.txt
# 25805455
# Ranked sets saved to starting_solution\TSP\St70\trial_17\BeamSplitter.txt
# 13442257
# Ranked sets saved to starting_solution\TSP\St70\trial_18\BeamSplitter.txt
# 38343372
# Ranked sets saved to starting_solution\TSP\St70\trial_19\BeamSplitter.txt
# 36869271
# Ranked sets saved to starting_solution\TSP\St70\trial_20\BeamSplitter.txt
# 44421452
# Ranked sets saved to starting_solution\TSP\St70\trial_21\BeamSplitter.txt
# 21412060
# Ranked sets saved to starting_solution\TSP\St70\trial_22\BeamSplitter.txt
# 36523416
# Ranked sets saved to starting_solution\TSP\St70\trial_23\BeamSplitter.txt
# 11635002
# Ranked sets saved to starting_solution\TSP\St70\trial_24\BeamSplitter.txt
# 34431129
# Ranked sets saved to starting_solution\TSP\St70\trial_25\BeamSplitter.txt
# 3583069
# Ranked sets saved to starting_solution\TSP\St70\trial_26\BeamSplitter.txt
# 14002624
# Ranked sets saved to starting_solution\TSP\St70\trial_27\BeamSplitter.txt
# 12861838
# Ranked sets saved to starting_solution\TSP\St70\trial_28\BeamSplitter.txt
# 58223188
# Ranked sets saved to starting_solution\TSP\St70\trial_29\BeamSplitter.txt
# 64985569
# Ranked sets saved to starting_solution\TSP\St70\trial_30\BeamSplitter.txt
# 22616397

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\St70"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Ibm, num_city = 70, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\St70\trial_11\Ibm.txt
# 71588171
# Ranked sets saved to starting_solution\TSP\St70\trial_12\Ibm.txt
# 14478707
# Ranked sets saved to starting_solution\TSP\St70\trial_13\Ibm.txt
# 51878397
# Ranked sets saved to starting_solution\TSP\St70\trial_14\Ibm.txt
# 22382719
# Ranked sets saved to starting_solution\TSP\St70\trial_15\Ibm.txt
# 28720934
# Ranked sets saved to starting_solution\TSP\St70\trial_16\Ibm.txt
# 51955324
# Ranked sets saved to starting_solution\TSP\St70\trial_17\Ibm.txt
# 53143758
# Ranked sets saved to starting_solution\TSP\St70\trial_18\Ibm.txt
# 62553026
# Ranked sets saved to starting_solution\TSP\St70\trial_19\Ibm.txt
# 38494955
# Ranked sets saved to starting_solution\TSP\St70\trial_20\Ibm.txt
# 28586294
# Ranked sets saved to starting_solution\TSP\St70\trial_21\Ibm.txt
# 4261643
# Ranked sets saved to starting_solution\TSP\St70\trial_22\Ibm.txt
# 60609176
# Ranked sets saved to starting_solution\TSP\St70\trial_23\Ibm.txt
# 68676632
# Ranked sets saved to starting_solution\TSP\St70\trial_24\Ibm.txt
# 70218906
# Ranked sets saved to starting_solution\TSP\St70\trial_25\Ibm.txt
# 10609879
# Ranked sets saved to starting_solution\TSP\St70\trial_26\Ibm.txt
# 12879317
# Ranked sets saved to starting_solution\TSP\St70\trial_27\Ibm.txt
# 16208022
# Ranked sets saved to starting_solution\TSP\St70\trial_28\Ibm.txt
# 497330
# Ranked sets saved to starting_solution\TSP\St70\trial_29\Ibm.txt
# 32035041
# Ranked sets saved to starting_solution\TSP\St70\trial_30\Ibm.txt
# 81971645

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\St70"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = QuasiRandom, num_city = 70, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\St70\trial_11\QuasiRandom.txt
# 30337147
# Ranked sets saved to starting_solution\TSP\St70\trial_12\QuasiRandom.txt
# 6518012
# Ranked sets saved to starting_solution\TSP\St70\trial_13\QuasiRandom.txt
# 63794372
# Ranked sets saved to starting_solution\TSP\St70\trial_14\QuasiRandom.txt
# 46607042
# Ranked sets saved to starting_solution\TSP\St70\trial_15\QuasiRandom.txt
# 16241429
# Ranked sets saved to starting_solution\TSP\St70\trial_16\QuasiRandom.txt
# 35867716
# Ranked sets saved to starting_solution\TSP\St70\trial_17\QuasiRandom.txt
# 49603333
# Ranked sets saved to starting_solution\TSP\St70\trial_18\QuasiRandom.txt
# 52715950
# Ranked sets saved to starting_solution\TSP\St70\trial_19\QuasiRandom.txt
# 37976312
# Ranked sets saved to starting_solution\TSP\St70\trial_20\QuasiRandom.txt
# 41552812
# Ranked sets saved to starting_solution\TSP\St70\trial_21\QuasiRandom.txt
# 62713218
# Ranked sets saved to starting_solution\TSP\St70\trial_22\QuasiRandom.txt
# 67729211
# Ranked sets saved to starting_solution\TSP\St70\trial_23\QuasiRandom.txt
# 25653064
# Ranked sets saved to starting_solution\TSP\St70\trial_24\QuasiRandom.txt
# 65384586
# Ranked sets saved to starting_solution\TSP\St70\trial_25\QuasiRandom.txt
# 16836789
# Ranked sets saved to starting_solution\TSP\St70\trial_26\QuasiRandom.txt
# 57470771
# Ranked sets saved to starting_solution\TSP\St70\trial_27\QuasiRandom.txt
# 41225831
# Ranked sets saved to starting_solution\TSP\St70\trial_28\QuasiRandom.txt
# 4460833
# Ranked sets saved to starting_solution\TSP\St70\trial_29\QuasiRandom.txt
# 9543553
# Ranked sets saved to starting_solution\TSP\St70\trial_30\QuasiRandom.txt
# 2007439

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\TSP\St70"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")
	
	# Process the normalization data and save to the file
	start = process_normalization_TSP_data(data = Mt19937, num_city = 70, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Ranked sets saved to starting_solution\TSP\St70\trial_11\Mt19937.txt
# 22045625
# Ranked sets saved to starting_solution\TSP\St70\trial_12\Mt19937.txt
# 64428751
# Ranked sets saved to starting_solution\TSP\St70\trial_13\Mt19937.txt
# 72859127
# Ranked sets saved to starting_solution\TSP\St70\trial_14\Mt19937.txt
# 10226034
# Ranked sets saved to starting_solution\TSP\St70\trial_15\Mt19937.txt
# 58002841
# Ranked sets saved to starting_solution\TSP\St70\trial_16\Mt19937.txt
# 27637007
# Ranked sets saved to starting_solution\TSP\St70\trial_17\Mt19937.txt
# 63797842
# Ranked sets saved to starting_solution\TSP\St70\trial_18\Mt19937.txt
# 9409441
# Ranked sets saved to starting_solution\TSP\St70\trial_19\Mt19937.txt
# 8679302
# Ranked sets saved to starting_solution\TSP\St70\trial_20\Mt19937.txt
# 67616172
# Ranked sets saved to starting_solution\TSP\St70\trial_21\Mt19937.txt
# 29088890
# Ranked sets saved to starting_solution\TSP\St70\trial_22\Mt19937.txt
# 34855575
# Ranked sets saved to starting_solution\TSP\St70\trial_23\Mt19937.txt
# 48913452
# Ranked sets saved to starting_solution\TSP\St70\trial_24\Mt19937.txt
# 29901355
# Ranked sets saved to starting_solution\TSP\St70\trial_25\Mt19937.txt
# 23115301
# Ranked sets saved to starting_solution\TSP\St70\trial_26\Mt19937.txt
# 56857067
# Ranked sets saved to starting_solution\TSP\St70\trial_27\Mt19937.txt
# 62237294
# Ranked sets saved to starting_solution\TSP\St70\trial_28\Mt19937.txt
# 80212906
# Ranked sets saved to starting_solution\TSP\St70\trial_29\Mt19937.txt
# 74703163
# Ranked sets saved to starting_solution\TSP\St70\trial_30\Mt19937.txt
# 67970683

# %% [markdown]
# # <span style="color:blue; font-weight:bold;">Maxcut init</span>

# %%
def process_normalization_Maxcut_data(data, num_city, file_path, pop_size=100):
    """
    Process the normalization data by creating binary sets (0 for even, 1 for odd based on the last decimal digit)
    and save them to a file.

    Parameters:
    - data (list or numpy array): The input data.
    - num_city (int): Number of cities in each set.
    - pop_size (int): Population size (number of sets).
    - file_path (str): Path to save the binary sets.

    Returns:
    - int: Starting position used to extract the data.
    """
    total_numbers_needed = num_city * pop_size
    data_len = len(data)

    # Ensure the data has enough numbers to wrap around
    if data_len < num_city:
        raise ValueError(f"Not enough data points. The data must be at least {num_city} long.")

    # Randomly choose a starting position
    start_position = np.random.randint(0, data_len)

    # Extract the required subset of data with wrapping
    selected_data = []
    for i in range(total_numbers_needed):
        selected_data.append(data[(start_position + i) % data_len])

    # Split the data into `pop_size` sets, each with `num_city` numbers
    sets = np.array(selected_data).reshape(pop_size, num_city)

    # Convert each number in each set to 0 if the last digit is even, 1 if odd
    binary_sets = []
    for s in sets:
        binary = []
        for x in s:
            # Get the last digit of the decimal number
            last_digit = int(str(x)[-1])  # Convert to string and extract the last character
            binary.append(0 if last_digit % 2 == 0 else 1)  # 0 for even, 1 for odd
        binary_sets.append(binary)

    # Save the binary sets to the specified file path
    with open(file_path, 'w') as file:
        for binary_set in binary_sets:
            file.write(" ".join(map(str, binary_set)) + "\n")

    print(f"Binary sets saved to {file_path}")
    return start_position

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">brock200_2.clq</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_2"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = BeamSplitter, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_11\BeamSplitter.txt
# 40398763
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_12\BeamSplitter.txt
# 60527153
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_13\BeamSplitter.txt
# 42169229
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_14\BeamSplitter.txt
# 80006548
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_15\BeamSplitter.txt
# 26048834
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_16\BeamSplitter.txt
# 73386975
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_17\BeamSplitter.txt
# 40828263
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_18\BeamSplitter.txt
# 24549277
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_19\BeamSplitter.txt
# 52969476
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_20\BeamSplitter.txt
# 50051954
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_21\BeamSplitter.txt
# 45749372
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_22\BeamSplitter.txt
# 77091967
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_23\BeamSplitter.txt
# 43356881
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_24\BeamSplitter.txt
# 47642425
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_25\BeamSplitter.txt
# 36230238
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_26\BeamSplitter.txt
# 3358551
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_27\BeamSplitter.txt
# 57223671
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_28\BeamSplitter.txt
# 3469232
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_29\BeamSplitter.txt
# 52281198
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_30\BeamSplitter.txt
# 50435769

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_2"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Ibm, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_11\Ibm.txt
# 10517604
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_12\Ibm.txt
# 94397
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_13\Ibm.txt
# 60827161
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_14\Ibm.txt
# 5526177
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_15\Ibm.txt
# 43703948
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_16\Ibm.txt
# 74849846
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_17\Ibm.txt
# 1391528
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_18\Ibm.txt
# 10231141
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_19\Ibm.txt
# 70682632
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_20\Ibm.txt
# 33865645
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_21\Ibm.txt
# 43793781
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_22\Ibm.txt
# 20370766
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_23\Ibm.txt
# 194023
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_24\Ibm.txt
# 15956115
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_25\Ibm.txt
# 75240290
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_26\Ibm.txt
# 21303098
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_27\Ibm.txt
# 75837095
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_28\Ibm.txt
# 81089555
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_29\Ibm.txt
# 51186807
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_30\Ibm.txt
# 77441802

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_2"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file paths
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = QuasiRandom, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_11\QuasiRandom.txt
# 65827345
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_12\QuasiRandom.txt
# 34523948
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_13\QuasiRandom.txt
# 71113006
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_14\QuasiRandom.txt
# 13928859
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_15\QuasiRandom.txt
# 34450070
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_16\QuasiRandom.txt
# 56750680
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_17\QuasiRandom.txt
# 23011208
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_18\QuasiRandom.txt
# 46319405
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_19\QuasiRandom.txt
# 68061978
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_20\QuasiRandom.txt
# 45772849
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_21\QuasiRandom.txt
# 9776701
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_22\QuasiRandom.txt
# 15653095
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_23\QuasiRandom.txt
# 43915629
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_24\QuasiRandom.txt
# 32449297
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_25\QuasiRandom.txt
# 70135122
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_26\QuasiRandom.txt
# 72642203
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_27\QuasiRandom.txt
# 56093029
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_28\QuasiRandom.txt
# 63633246
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_29\QuasiRandom.txt
# 13013709
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_30\QuasiRandom.txt
# 44562612

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_2"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Mt19937, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_11\Mt19937.txt
# 39045715
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_12\Mt19937.txt
# 14086678
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_13\Mt19937.txt
# 66662209
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_14\Mt19937.txt
# 20218389
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_15\Mt19937.txt
# 35214183
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_16\Mt19937.txt
# 23456074
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_17\Mt19937.txt
# 71009039
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_18\Mt19937.txt
# 5090418
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_19\Mt19937.txt
# 56383401
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_20\Mt19937.txt
# 1825239
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_21\Mt19937.txt
# 82227115
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_22\Mt19937.txt
# 50629712
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_23\Mt19937.txt
# 44167923
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_24\Mt19937.txt
# 37150342
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_25\Mt19937.txt
# 8651575
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_26\Mt19937.txt
# 62693860
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_27\Mt19937.txt
# 26557778
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_28\Mt19937.txt
# 19337563
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_29\Mt19937.txt
# 3311224
# Binary sets saved to starting_solution\maxcut\Brock200_2\trial_30\Mt19937.txt
# 8204685

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">brock200_4.clq</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = BeamSplitter, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_11\BeamSplitter.txt
# 72782233
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_12\BeamSplitter.txt
# 49596977
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_13\BeamSplitter.txt
# 75676958
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_14\BeamSplitter.txt
# 22015216
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_15\BeamSplitter.txt
# 33093657
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_16\BeamSplitter.txt
# 18622418
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_17\BeamSplitter.txt
# 68426376
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_18\BeamSplitter.txt
# 27382929
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_19\BeamSplitter.txt
# 42848232
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_20\BeamSplitter.txt
# 65122776
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_21\BeamSplitter.txt
# 74231196
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_22\BeamSplitter.txt
# 43912589
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_23\BeamSplitter.txt
# 43194586
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_24\BeamSplitter.txt
# 18373695
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_25\BeamSplitter.txt
# 52034088
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_26\BeamSplitter.txt
# 10839925
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_27\BeamSplitter.txt
# 2066445
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_28\BeamSplitter.txt
# 43687968
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_29\BeamSplitter.txt
# 11171101
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_30\BeamSplitter.txt
# 74928214

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Ibm, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_11\Ibm.txt
# 23628502
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_12\Ibm.txt
# 72313460
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_13\Ibm.txt
# 15952423
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_14\Ibm.txt
# 180650
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_15\Ibm.txt
# 35239992
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_16\Ibm.txt
# 1757086
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_17\Ibm.txt
# 75095080
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_18\Ibm.txt
# 12380513
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_19\Ibm.txt
# 43012982
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_20\Ibm.txt
# 63492161
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_21\Ibm.txt
# 64676787
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_22\Ibm.txt
# 77585783
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_23\Ibm.txt
# 7599954
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_24\Ibm.txt
# 12747857
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_25\Ibm.txt
# 52872613
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_26\Ibm.txt
# 63796473
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_27\Ibm.txt
# 20341309
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_28\Ibm.txt
# 16178327
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_29\Ibm.txt
# 54088452
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_30\Ibm.txt
# 23265084

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file paths
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = QuasiRandom, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_11\QuasiRandom.txt
# 49055962
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_12\QuasiRandom.txt
# 38039235
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_13\QuasiRandom.txt
# 18255872
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_14\QuasiRandom.txt
# 68324077
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_15\QuasiRandom.txt
# 35750990
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_16\QuasiRandom.txt
# 46230853
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_17\QuasiRandom.txt
# 76748570
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_18\QuasiRandom.txt
# 81278543
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_19\QuasiRandom.txt
# 79649660
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_20\QuasiRandom.txt
# 72493795
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_21\QuasiRandom.txt
# 40662381
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_22\QuasiRandom.txt
# 14504747
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_23\QuasiRandom.txt
# 80328553
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_24\QuasiRandom.txt
# 34795021
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_25\QuasiRandom.txt
# 42788110
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_26\QuasiRandom.txt
# 31329890
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_27\QuasiRandom.txt
# 13777384
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_28\QuasiRandom.txt
# 29366175
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_29\QuasiRandom.txt
# 57465133
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_30\QuasiRandom.txt
# 21106704

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Brock200_4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Mt19937, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_11\Mt19937.txt
# 29555213
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_12\Mt19937.txt
# 23997770
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_13\Mt19937.txt
# 3035694
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_14\Mt19937.txt
# 70354563
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_15\Mt19937.txt
# 78816678
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_16\Mt19937.txt
# 56903508
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_17\Mt19937.txt
# 14311105
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_18\Mt19937.txt
# 2581721
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_19\Mt19937.txt
# 2901828
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_20\Mt19937.txt
# 17658905
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_21\Mt19937.txt
# 28003467
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_22\Mt19937.txt
# 6864410
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_23\Mt19937.txt
# 25715100
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_24\Mt19937.txt
# 68788291
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_25\Mt19937.txt
# 13229461
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_26\Mt19937.txt
# 55451522
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_27\Mt19937.txt
# 7875428
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_28\Mt19937.txt
# 27590141
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_29\Mt19937.txt
# 34745214
# Binary sets saved to starting_solution\maxcut\Brock200_4\trial_30\Mt19937.txt
# 33038253

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">C125.9.clq</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\C125.9"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = BeamSplitter, num_city = 125, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\C125.9\trial_11\BeamSplitter.txt
# 63325093
# Binary sets saved to starting_solution\maxcut\C125.9\trial_12\BeamSplitter.txt
# 60943929
# Binary sets saved to starting_solution\maxcut\C125.9\trial_13\BeamSplitter.txt
# 75864222
# Binary sets saved to starting_solution\maxcut\C125.9\trial_14\BeamSplitter.txt
# 69681628
# Binary sets saved to starting_solution\maxcut\C125.9\trial_15\BeamSplitter.txt
# 4797451
# Binary sets saved to starting_solution\maxcut\C125.9\trial_16\BeamSplitter.txt
# 36335460
# Binary sets saved to starting_solution\maxcut\C125.9\trial_17\BeamSplitter.txt
# 56250462
# Binary sets saved to starting_solution\maxcut\C125.9\trial_18\BeamSplitter.txt
# 27504448
# Binary sets saved to starting_solution\maxcut\C125.9\trial_19\BeamSplitter.txt
# 69315675
# Binary sets saved to starting_solution\maxcut\C125.9\trial_20\BeamSplitter.txt
# 6985015
# Binary sets saved to starting_solution\maxcut\C125.9\trial_21\BeamSplitter.txt
# 79540259
# Binary sets saved to starting_solution\maxcut\C125.9\trial_22\BeamSplitter.txt
# 72373141
# Binary sets saved to starting_solution\maxcut\C125.9\trial_23\BeamSplitter.txt
# 33594992
# Binary sets saved to starting_solution\maxcut\C125.9\trial_24\BeamSplitter.txt
# 70488801
# Binary sets saved to starting_solution\maxcut\C125.9\trial_25\BeamSplitter.txt
# 67772522
# Binary sets saved to starting_solution\maxcut\C125.9\trial_26\BeamSplitter.txt
# 25319403
# Binary sets saved to starting_solution\maxcut\C125.9\trial_27\BeamSplitter.txt
# 17646926
# Binary sets saved to starting_solution\maxcut\C125.9\trial_28\BeamSplitter.txt
# 56547186
# Binary sets saved to starting_solution\maxcut\C125.9\trial_29\BeamSplitter.txt
# 5766675
# Binary sets saved to starting_solution\maxcut\C125.9\trial_30\BeamSplitter.txt
# 6588438

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\C125.9"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Ibm, num_city = 125, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\C125.9\trial_11\Ibm.txt
# 32229415
# Binary sets saved to starting_solution\maxcut\C125.9\trial_12\Ibm.txt
# 70715857
# Binary sets saved to starting_solution\maxcut\C125.9\trial_13\Ibm.txt
# 80802104
# Binary sets saved to starting_solution\maxcut\C125.9\trial_14\Ibm.txt
# 4973345
# Binary sets saved to starting_solution\maxcut\C125.9\trial_15\Ibm.txt
# 73313896
# Binary sets saved to starting_solution\maxcut\C125.9\trial_16\Ibm.txt
# 13084548
# Binary sets saved to starting_solution\maxcut\C125.9\trial_17\Ibm.txt
# 45429914
# Binary sets saved to starting_solution\maxcut\C125.9\trial_18\Ibm.txt
# 24473307
# Binary sets saved to starting_solution\maxcut\C125.9\trial_19\Ibm.txt
# 76009660
# Binary sets saved to starting_solution\maxcut\C125.9\trial_20\Ibm.txt
# 51992964
# Binary sets saved to starting_solution\maxcut\C125.9\trial_21\Ibm.txt
# 65281254
# Binary sets saved to starting_solution\maxcut\C125.9\trial_22\Ibm.txt
# 80686465
# Binary sets saved to starting_solution\maxcut\C125.9\trial_23\Ibm.txt
# 7639994
# Binary sets saved to starting_solution\maxcut\C125.9\trial_24\Ibm.txt
# 50180598
# Binary sets saved to starting_solution\maxcut\C125.9\trial_25\Ibm.txt
# 51097792
# Binary sets saved to starting_solution\maxcut\C125.9\trial_26\Ibm.txt
# 23803838
# Binary sets saved to starting_solution\maxcut\C125.9\trial_27\Ibm.txt
# 82227233
# Binary sets saved to starting_solution\maxcut\C125.9\trial_28\Ibm.txt
# 77733422
# Binary sets saved to starting_solution\maxcut\C125.9\trial_29\Ibm.txt
# 11655368
# Binary sets saved to starting_solution\maxcut\C125.9\trial_30\Ibm.txt
# 6890924

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\C125.9"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file paths
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = QuasiRandom, num_city = 125, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\C125.9\trial_11\QuasiRandom.txt
# 5771011
# Binary sets saved to starting_solution\maxcut\C125.9\trial_12\QuasiRandom.txt
# 38408533
# Binary sets saved to starting_solution\maxcut\C125.9\trial_13\QuasiRandom.txt
# 44938577
# Binary sets saved to starting_solution\maxcut\C125.9\trial_14\QuasiRandom.txt
# 55978454
# Binary sets saved to starting_solution\maxcut\C125.9\trial_15\QuasiRandom.txt
# 62920019
# Binary sets saved to starting_solution\maxcut\C125.9\trial_16\QuasiRandom.txt
# 55860916
# Binary sets saved to starting_solution\maxcut\C125.9\trial_17\QuasiRandom.txt
# 81478126
# Binary sets saved to starting_solution\maxcut\C125.9\trial_18\QuasiRandom.txt
# 62199530
# Binary sets saved to starting_solution\maxcut\C125.9\trial_19\QuasiRandom.txt
# 31179729
# Binary sets saved to starting_solution\maxcut\C125.9\trial_20\QuasiRandom.txt
# 25729443
# Binary sets saved to starting_solution\maxcut\C125.9\trial_21\QuasiRandom.txt
# 38986822
# Binary sets saved to starting_solution\maxcut\C125.9\trial_22\QuasiRandom.txt
# 27358261
# Binary sets saved to starting_solution\maxcut\C125.9\trial_23\QuasiRandom.txt
# 49532736
# Binary sets saved to starting_solution\maxcut\C125.9\trial_24\QuasiRandom.txt
# 46537766
# Binary sets saved to starting_solution\maxcut\C125.9\trial_25\QuasiRandom.txt
# 46201347
# Binary sets saved to starting_solution\maxcut\C125.9\trial_26\QuasiRandom.txt
# 39608576
# Binary sets saved to starting_solution\maxcut\C125.9\trial_27\QuasiRandom.txt
# 58595635
# Binary sets saved to starting_solution\maxcut\C125.9\trial_28\QuasiRandom.txt
# 37855842
# Binary sets saved to starting_solution\maxcut\C125.9\trial_29\QuasiRandom.txt
# 54146948
# Binary sets saved to starting_solution\maxcut\C125.9\trial_30\QuasiRandom.txt
# 35042061

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\C125.9"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Mt19937, num_city = 125, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\C125.9\trial_11\Mt19937.txt
# 10128946
# Binary sets saved to starting_solution\maxcut\C125.9\trial_12\Mt19937.txt
# 60926340
# Binary sets saved to starting_solution\maxcut\C125.9\trial_13\Mt19937.txt
# 34156135
# Binary sets saved to starting_solution\maxcut\C125.9\trial_14\Mt19937.txt
# 2446236
# Binary sets saved to starting_solution\maxcut\C125.9\trial_15\Mt19937.txt
# 6605722
# Binary sets saved to starting_solution\maxcut\C125.9\trial_16\Mt19937.txt
# 63596948
# Binary sets saved to starting_solution\maxcut\C125.9\trial_17\Mt19937.txt
# 4747723
# Binary sets saved to starting_solution\maxcut\C125.9\trial_18\Mt19937.txt
# 45993884
# Binary sets saved to starting_solution\maxcut\C125.9\trial_19\Mt19937.txt
# 70905205
# Binary sets saved to starting_solution\maxcut\C125.9\trial_20\Mt19937.txt
# 669131
# Binary sets saved to starting_solution\maxcut\C125.9\trial_21\Mt19937.txt
# 64033638
# Binary sets saved to starting_solution\maxcut\C125.9\trial_22\Mt19937.txt
# 60986712
# Binary sets saved to starting_solution\maxcut\C125.9\trial_23\Mt19937.txt
# 2036395
# Binary sets saved to starting_solution\maxcut\C125.9\trial_24\Mt19937.txt
# 14056016
# Binary sets saved to starting_solution\maxcut\C125.9\trial_25\Mt19937.txt
# 42955787
# Binary sets saved to starting_solution\maxcut\C125.9\trial_26\Mt19937.txt
# 64254663
# Binary sets saved to starting_solution\maxcut\C125.9\trial_27\Mt19937.txt
# 43821772
# Binary sets saved to starting_solution\maxcut\C125.9\trial_28\Mt19937.txt
# 55489123
# Binary sets saved to starting_solution\maxcut\C125.9\trial_29\Mt19937.txt
# 22717182
# Binary sets saved to starting_solution\maxcut\C125.9\trial_30\Mt19937.txt
# 23133956

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">gen200_p0.9_44.b.clq</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\gen200_p0.9_44.b"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = BeamSplitter, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_11\BeamSplitter.txt
# 56536481
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_12\BeamSplitter.txt
# 54788766
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_13\BeamSplitter.txt
# 58499964
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_14\BeamSplitter.txt
# 75822531
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_15\BeamSplitter.txt
# 28595234
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_16\BeamSplitter.txt
# 80757001
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_17\BeamSplitter.txt
# 23518383
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_18\BeamSplitter.txt
# 20421230
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_19\BeamSplitter.txt
# 25943658
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_20\BeamSplitter.txt
# 38063483
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_21\BeamSplitter.txt
# 42492038
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_22\BeamSplitter.txt
# 36559468
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_23\BeamSplitter.txt
# 61190479
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_24\BeamSplitter.txt
# 67226536
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_25\BeamSplitter.txt
# 81732918
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_26\BeamSplitter.txt
# 64924989
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_27\BeamSplitter.txt
# 18437063
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_28\BeamSplitter.txt
# 44473819
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_29\BeamSplitter.txt
# 35387101
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_30\BeamSplitter.txt
# 34475926

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\gen200_p0.9_44.b"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Ibm, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_11\Ibm.txt
# 53203878
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_12\Ibm.txt
# 4918686
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_13\Ibm.txt
# 47036726
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_14\Ibm.txt
# 34151245
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_15\Ibm.txt
# 77645876
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_16\Ibm.txt
# 39487465
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_17\Ibm.txt
# 62485723
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_18\Ibm.txt
# 159626
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_19\Ibm.txt
# 68527419
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_20\Ibm.txt
# 78821940
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_21\Ibm.txt
# 11979103
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_22\Ibm.txt
# 76484394
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_23\Ibm.txt
# 61605279
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_24\Ibm.txt
# 36802402
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_25\Ibm.txt
# 50316992
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_26\Ibm.txt
# 72046245
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_27\Ibm.txt
# 66580558
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_28\Ibm.txt
# 69173847
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_29\Ibm.txt
# 70683626
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_30\Ibm.txt
# 12231586

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\gen200_p0.9_44.b"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file paths
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = QuasiRandom, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_11\QuasiRandom.txt
# 64068895
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_12\QuasiRandom.txt
# 43326610
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_13\QuasiRandom.txt
# 31525362
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_14\QuasiRandom.txt
# 65006935
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_15\QuasiRandom.txt
# 39869958
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_16\QuasiRandom.txt
# 61255193
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_17\QuasiRandom.txt
# 18442246
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_18\QuasiRandom.txt
# 22076462
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_19\QuasiRandom.txt
# 16242552
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_20\QuasiRandom.txt
# 39826673
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_21\QuasiRandom.txt
# 22751314
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_22\QuasiRandom.txt
# 4174758
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_23\QuasiRandom.txt
# 19316495
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_24\QuasiRandom.txt
# 599703
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_25\QuasiRandom.txt
# 16924474
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_26\QuasiRandom.txt
# 76440841
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_27\QuasiRandom.txt
# 56444209
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_28\QuasiRandom.txt
# 36318789
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_29\QuasiRandom.txt
# 47655922
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_30\QuasiRandom.txt
# 35460878

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\gen200_p0.9_44.b"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Mt19937, num_city = 200, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_11\Mt19937.txt
# 55807554
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_12\Mt19937.txt
# 28886336
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_13\Mt19937.txt
# 78220169
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_14\Mt19937.txt
# 18589473
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_15\Mt19937.txt
# 69014102
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_16\Mt19937.txt
# 24862773
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_17\Mt19937.txt
# 22084576
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_18\Mt19937.txt
# 36233252
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_19\Mt19937.txt
# 46823116
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_20\Mt19937.txt
# 16199174
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_21\Mt19937.txt
# 52886095
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_22\Mt19937.txt
# 13966461
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_23\Mt19937.txt
# 58353743
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_24\Mt19937.txt
# 3064448
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_25\Mt19937.txt
# 80488615
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_26\Mt19937.txt
# 30795120
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_27\Mt19937.txt
# 19262872
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_28\Mt19937.txt
# 51130871
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_29\Mt19937.txt
# 81566722
# Binary sets saved to starting_solution\maxcut\gen200_p0.9_44.b\trial_30\Mt19937.txt
# 29836959

# %% [markdown]
# #### <span style="color:green; font-weight:bold;">keller4.clq</span>

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Keller4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = BeamSplitter, num_city = 171, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Keller4\trial_11\BeamSplitter.txt
# 51029153
# Binary sets saved to starting_solution\maxcut\Keller4\trial_12\BeamSplitter.txt
# 75149528
# Binary sets saved to starting_solution\maxcut\Keller4\trial_13\BeamSplitter.txt
# 36359810
# Binary sets saved to starting_solution\maxcut\Keller4\trial_14\BeamSplitter.txt
# 60234504
# Binary sets saved to starting_solution\maxcut\Keller4\trial_15\BeamSplitter.txt
# 58979196
# Binary sets saved to starting_solution\maxcut\Keller4\trial_16\BeamSplitter.txt
# 36900119
# Binary sets saved to starting_solution\maxcut\Keller4\trial_17\BeamSplitter.txt
# 30889177
# Binary sets saved to starting_solution\maxcut\Keller4\trial_18\BeamSplitter.txt
# 65329207
# Binary sets saved to starting_solution\maxcut\Keller4\trial_19\BeamSplitter.txt
# 32687238
# Binary sets saved to starting_solution\maxcut\Keller4\trial_20\BeamSplitter.txt
# 37143785
# Binary sets saved to starting_solution\maxcut\Keller4\trial_21\BeamSplitter.txt
# 25638884
# Binary sets saved to starting_solution\maxcut\Keller4\trial_22\BeamSplitter.txt
# 77545477
# Binary sets saved to starting_solution\maxcut\Keller4\trial_23\BeamSplitter.txt
# 42674772
# Binary sets saved to starting_solution\maxcut\Keller4\trial_24\BeamSplitter.txt
# 32925049
# Binary sets saved to starting_solution\maxcut\Keller4\trial_25\BeamSplitter.txt
# 77979963
# Binary sets saved to starting_solution\maxcut\Keller4\trial_26\BeamSplitter.txt
# 67072662
# Binary sets saved to starting_solution\maxcut\Keller4\trial_27\BeamSplitter.txt
# 3078285
# Binary sets saved to starting_solution\maxcut\Keller4\trial_28\BeamSplitter.txt
# 19182107
# Binary sets saved to starting_solution\maxcut\Keller4\trial_29\BeamSplitter.txt
# 60376069
# Binary sets saved to starting_solution\maxcut\Keller4\trial_30\BeamSplitter.txt
# 55694872

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Keller4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Ibm.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Ibm, num_city = 171, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Keller4\trial_11\Ibm.txt
# 81726283
# Binary sets saved to starting_solution\maxcut\Keller4\trial_12\Ibm.txt
# 40565436
# Binary sets saved to starting_solution\maxcut\Keller4\trial_13\Ibm.txt
# 46279462
# Binary sets saved to starting_solution\maxcut\Keller4\trial_14\Ibm.txt
# 13729974
# Binary sets saved to starting_solution\maxcut\Keller4\trial_15\Ibm.txt
# 19401303
# Binary sets saved to starting_solution\maxcut\Keller4\trial_16\Ibm.txt
# 41286090
# Binary sets saved to starting_solution\maxcut\Keller4\trial_17\Ibm.txt
# 78342694
# Binary sets saved to starting_solution\maxcut\Keller4\trial_18\Ibm.txt
# 4751497
# Binary sets saved to starting_solution\maxcut\Keller4\trial_19\Ibm.txt
# 858208
# Binary sets saved to starting_solution\maxcut\Keller4\trial_20\Ibm.txt
# 41853179
# Binary sets saved to starting_solution\maxcut\Keller4\trial_21\Ibm.txt
# 39640965
# Binary sets saved to starting_solution\maxcut\Keller4\trial_22\Ibm.txt
# 23421813
# Binary sets saved to starting_solution\maxcut\Keller4\trial_23\Ibm.txt
# 87078
# Binary sets saved to starting_solution\maxcut\Keller4\trial_24\Ibm.txt
# 76764719
# Binary sets saved to starting_solution\maxcut\Keller4\trial_25\Ibm.txt
# 67535985
# Binary sets saved to starting_solution\maxcut\Keller4\trial_26\Ibm.txt
# 3963030
# Binary sets saved to starting_solution\maxcut\Keller4\trial_27\Ibm.txt
# 6851408
# Binary sets saved to starting_solution\maxcut\Keller4\trial_28\Ibm.txt
# 54205580
# Binary sets saved to starting_solution\maxcut\Keller4\trial_29\Ibm.txt
# 38580511
# Binary sets saved to starting_solution\maxcut\Keller4\trial_30\Ibm.txt
# 74622731

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Keller4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file paths
	output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = QuasiRandom, num_city = 171, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Keller4\trial_11\QuasiRandom.txt
# 48890139
# Binary sets saved to starting_solution\maxcut\Keller4\trial_12\QuasiRandom.txt
# 74819653
# Binary sets saved to starting_solution\maxcut\Keller4\trial_13\QuasiRandom.txt
# 79746555
# Binary sets saved to starting_solution\maxcut\Keller4\trial_14\QuasiRandom.txt
# 23919638
# Binary sets saved to starting_solution\maxcut\Keller4\trial_15\QuasiRandom.txt
# 76855681
# Binary sets saved to starting_solution\maxcut\Keller4\trial_16\QuasiRandom.txt
# 35321828
# Binary sets saved to starting_solution\maxcut\Keller4\trial_17\QuasiRandom.txt
# 12744425
# Binary sets saved to starting_solution\maxcut\Keller4\trial_18\QuasiRandom.txt
# 14512654
# Binary sets saved to starting_solution\maxcut\Keller4\trial_19\QuasiRandom.txt
# 67621450
# Binary sets saved to starting_solution\maxcut\Keller4\trial_20\QuasiRandom.txt
# 74445996
# Binary sets saved to starting_solution\maxcut\Keller4\trial_21\QuasiRandom.txt
# 27823073
# Binary sets saved to starting_solution\maxcut\Keller4\trial_22\QuasiRandom.txt
# 80003279
# Binary sets saved to starting_solution\maxcut\Keller4\trial_23\QuasiRandom.txt
# 29543553
# Binary sets saved to starting_solution\maxcut\Keller4\trial_24\QuasiRandom.txt
# 47413326
# Binary sets saved to starting_solution\maxcut\Keller4\trial_25\QuasiRandom.txt
# 74281423
# Binary sets saved to starting_solution\maxcut\Keller4\trial_26\QuasiRandom.txt
# 28026473
# Binary sets saved to starting_solution\maxcut\Keller4\trial_27\QuasiRandom.txt
# 79790515
# Binary sets saved to starting_solution\maxcut\Keller4\trial_28\QuasiRandom.txt
# 54153374
# Binary sets saved to starting_solution\maxcut\Keller4\trial_29\QuasiRandom.txt
# 18683699
# Binary sets saved to starting_solution\maxcut\Keller4\trial_30\QuasiRandom.txt
# 65119161

# %%
# Ensure the directory exists
base_output_dir  = "starting_solution\maxcut\Keller4"

for i in range(11, num_trials + 1):	
	# Define the subdirectory for each trial
	trial_dir = os.path.join(base_output_dir, f"trial_{i}")
	
	# Ensure the trial directory exists
	os.makedirs(trial_dir, exist_ok=True)
	
	# Define the file path
	output_file_path = os.path.join(trial_dir, "Mt19937.txt")

	# Process the normalization data and save to the file
	start = process_normalization_Maxcut_data(data = Mt19937, num_city = 171, pop_size = 100, file_path = output_file_path)

	# Print the expected output format
	print(start)
# Out:
# Binary sets saved to starting_solution\maxcut\Keller4\trial_11\Mt19937.txt
# 27556252
# Binary sets saved to starting_solution\maxcut\Keller4\trial_12\Mt19937.txt
# 25692981
# Binary sets saved to starting_solution\maxcut\Keller4\trial_13\Mt19937.txt
# 73197260
# Binary sets saved to starting_solution\maxcut\Keller4\trial_14\Mt19937.txt
# 12424368
# Binary sets saved to starting_solution\maxcut\Keller4\trial_15\Mt19937.txt
# 81959090
# Binary sets saved to starting_solution\maxcut\Keller4\trial_16\Mt19937.txt
# 3064384
# Binary sets saved to starting_solution\maxcut\Keller4\trial_17\Mt19937.txt
# 33182268
# Binary sets saved to starting_solution\maxcut\Keller4\trial_18\Mt19937.txt
# 6262722
# Binary sets saved to starting_solution\maxcut\Keller4\trial_19\Mt19937.txt
# 77089765
# Binary sets saved to starting_solution\maxcut\Keller4\trial_20\Mt19937.txt
# 8789980
# Binary sets saved to starting_solution\maxcut\Keller4\trial_21\Mt19937.txt
# 80126210
# Binary sets saved to starting_solution\maxcut\Keller4\trial_22\Mt19937.txt
# 40169210
# Binary sets saved to starting_solution\maxcut\Keller4\trial_23\Mt19937.txt
# 35435836
# Binary sets saved to starting_solution\maxcut\Keller4\trial_24\Mt19937.txt
# 52241
# Binary sets saved to starting_solution\maxcut\Keller4\trial_25\Mt19937.txt
# 60128298
# Binary sets saved to starting_solution\maxcut\Keller4\trial_26\Mt19937.txt
# 2961707
# Binary sets saved to starting_solution\maxcut\Keller4\trial_27\Mt19937.txt
# 67047676
# Binary sets saved to starting_solution\maxcut\Keller4\trial_28\Mt19937.txt
# 48980833
# Binary sets saved to starting_solution\maxcut\Keller4\trial_29\Mt19937.txt
# 77934816
# Binary sets saved to starting_solution\maxcut\Keller4\trial_30\Mt19937.txt
# 6141807

# %% [markdown]
# # <span style="color:blue; font-weight:bold;">OPFUNU init</span>

# %% [markdown]
# ## <span style="color:blue; font-weight:bold;">F12021 init</span>

# %%
import numpy as np

def process_normalization_f12021_data(data, num_city, file_path, pop_size=100, bound=(-100, 100)):
    """
    Process the normalization data by scaling each number from range [0, 1] to a specified bound
    and save them to a file.

    Parameters:
    - data (list or numpy array): The input data (assumed to be in range [0, 1]).
    - num_city (int): Number of cities in each set.
    - pop_size (int): Population size (number of sets).
    - file_path (str): Path to save the normalized sets.
    - bound (tuple): The lower and upper bound for normalization (default is (-100, 100)).

    Returns:
    - int: Starting position used to extract the data.
    """
    total_numbers_needed = num_city * pop_size
    data_len = len(data)

    # Ensure the data has enough numbers to wrap around
    if data_len < num_city:
        raise ValueError(f"Not enough data points. The data must be at least {num_city} long.")

    # Randomly choose a starting position
    start_position = np.random.randint(0, data_len)

    # Extract the required subset of data with wrapping
    selected_data = [data[(start_position + i) % data_len] for i in range(total_numbers_needed)]

    # Split the data into `pop_size` sets, each with `num_city` numbers
    sets = np.array(selected_data).reshape(pop_size, num_city)

    # Normalize each number in each set from range [0, 1] to the specified bound
    lower_bound, upper_bound = bound
    range_size = upper_bound - lower_bound

    normalized_sets = []
    for s in sets:
        normalized = [int(x * range_size + lower_bound) for x in s]  # Scale dynamically
        normalized_sets.append(normalized)

    # Save the normalized sets to the specified file path
    with open(file_path, 'w') as file:
        for normalized_set in normalized_sets:
            file.write(" ".join(map(str, normalized_set)) + "\n")

    print(f"Normalized sets saved to {file_path}")
    return start_position

# %%
input_sets = [
    (10, (-100, 100)),  # First run: num_city = 10
    (10, (-100, 100)),  # Second run: num_city = 15
    (10, (-100, 100)),  # Third run: num_city = 20
    (10, (-100, 100)),  # Fourth run: num_city = 25
    (10, (-100, 100)),  # Fifth run: num_city = 30
    (10, (-100, 100)),  # Sixth run: num_city = 35
    (10, (-100, 100)),  # Seventh run: num_city = 40
    (10, (-100, 100)),  # Eighth run: num_city = 45
    (10, (-100, 100)),  # Ninth run: num_city = 50
    (10, (-100, 100))   # Tenth run: num_city = 55
]

# %%
num_trials = 30  # Number of trials per run

# %%
# Run the process 10 times, each with a different num_city value and saving in a new location
for run_index in range(1, 11):  # 10 separate runs
    num_city, bound = input_sets[run_index - 1]  # Get num_city and bound from the input set
    
    # Define the **run-specific** directory (F12021, F22021, ..., F102021)
    base_output_dir = os.path.join("starting_solution", "CEC2021", f"F{run_index}2021")
    os.makedirs(base_output_dir, exist_ok=True)  # Ensure the base directory exists
    
    # Run 10 trials per run
    for trial_index in range(11, num_trials + 1):  
        # Define the subdirectory for each trial
        trial_dir = os.path.join(base_output_dir, f"trial_{trial_index}")
        os.makedirs(trial_dir, exist_ok=True)  # Ensure the trial directory exists
        
        # Define the file path
        output_file_path = os.path.join(trial_dir, "BeamSplitter.txt")

        # Process the normalization data and save to the file
        start = process_normalization_f12021_data(
            data=BeamSplitter, 
            num_city=num_city, 
            pop_size=100, 
            file_path=output_file_path, 
            bound=bound
        )

        # Print the expected output format
        print(f"Run {run_index}, Trial {trial_index}: num_city={num_city}, bound={bound}, start_position={start}")
# Out:
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_11\BeamSplitter.txt
# Run 1, Trial 11: num_city=10, bound=(-100, 100), start_position=28174943
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_12\BeamSplitter.txt
# Run 1, Trial 12: num_city=10, bound=(-100, 100), start_position=11904841
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_13\BeamSplitter.txt
# Run 1, Trial 13: num_city=10, bound=(-100, 100), start_position=16037246
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_14\BeamSplitter.txt
# Run 1, Trial 14: num_city=10, bound=(-100, 100), start_position=35314441
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_15\BeamSplitter.txt
# Run 1, Trial 15: num_city=10, bound=(-100, 100), start_position=10076612
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_16\BeamSplitter.txt
# Run 1, Trial 16: num_city=10, bound=(-100, 100), start_position=72208427
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_17\BeamSplitter.txt
# Run 1, Trial 17: num_city=10, bound=(-100, 100), start_position=36948048
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_18\BeamSplitter.txt
# Run 1, Trial 18: num_city=10, bound=(-100, 100), start_position=53339135
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_19\BeamSplitter.txt
# Run 1, Trial 19: num_city=10, bound=(-100, 100), start_position=8937823
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_20\BeamSplitter.txt
# Run 1, Trial 20: num_city=10, bound=(-100, 100), start_position=38329326
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_21\BeamSplitter.txt
# Run 1, Trial 21: num_city=10, bound=(-100, 100), start_position=80088716
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_22\BeamSplitter.txt
# Run 1, Trial 22: num_city=10, bound=(-100, 100), start_position=32021979
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_23\BeamSplitter.txt
# Run 1, Trial 23: num_city=10, bound=(-100, 100), start_position=40396627
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_24\BeamSplitter.txt
# Run 1, Trial 24: num_city=10, bound=(-100, 100), start_position=59294761
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_25\BeamSplitter.txt
# Run 1, Trial 25: num_city=10, bound=(-100, 100), start_position=71427636
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_26\BeamSplitter.txt
# Run 1, Trial 26: num_city=10, bound=(-100, 100), start_position=30279811
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_27\BeamSplitter.txt
# Run 1, Trial 27: num_city=10, bound=(-100, 100), start_position=54164388
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_28\BeamSplitter.txt
# Run 1, Trial 28: num_city=10, bound=(-100, 100), start_position=78398358
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_29\BeamSplitter.txt
# Run 1, Trial 29: num_city=10, bound=(-100, 100), start_position=7224043
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_30\BeamSplitter.txt
# Run 1, Trial 30: num_city=10, bound=(-100, 100), start_position=41775962
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_11\BeamSplitter.txt
# Run 2, Trial 11: num_city=10, bound=(-100, 100), start_position=34262866
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_12\BeamSplitter.txt
# Run 2, Trial 12: num_city=10, bound=(-100, 100), start_position=29483215
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_13\BeamSplitter.txt
# Run 2, Trial 13: num_city=10, bound=(-100, 100), start_position=19912933
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_14\BeamSplitter.txt
# Run 2, Trial 14: num_city=10, bound=(-100, 100), start_position=42019662
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_15\BeamSplitter.txt
# Run 2, Trial 15: num_city=10, bound=(-100, 100), start_position=25534493
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_16\BeamSplitter.txt
# Run 2, Trial 16: num_city=10, bound=(-100, 100), start_position=14079693
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_17\BeamSplitter.txt
# Run 2, Trial 17: num_city=10, bound=(-100, 100), start_position=22558424
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_18\BeamSplitter.txt
# Run 2, Trial 18: num_city=10, bound=(-100, 100), start_position=23162117
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_19\BeamSplitter.txt
# Run 2, Trial 19: num_city=10, bound=(-100, 100), start_position=12346847
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_20\BeamSplitter.txt
# Run 2, Trial 20: num_city=10, bound=(-100, 100), start_position=24159205
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_21\BeamSplitter.txt
# Run 2, Trial 21: num_city=10, bound=(-100, 100), start_position=66750224
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_22\BeamSplitter.txt
# Run 2, Trial 22: num_city=10, bound=(-100, 100), start_position=52414525
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_23\BeamSplitter.txt
# Run 2, Trial 23: num_city=10, bound=(-100, 100), start_position=79941970
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_24\BeamSplitter.txt
# Run 2, Trial 24: num_city=10, bound=(-100, 100), start_position=5561515
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_25\BeamSplitter.txt
# Run 2, Trial 25: num_city=10, bound=(-100, 100), start_position=39623369
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_26\BeamSplitter.txt
# Run 2, Trial 26: num_city=10, bound=(-100, 100), start_position=19186616
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_27\BeamSplitter.txt
# Run 2, Trial 27: num_city=10, bound=(-100, 100), start_position=14612413
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_28\BeamSplitter.txt
# Run 2, Trial 28: num_city=10, bound=(-100, 100), start_position=61327930
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_29\BeamSplitter.txt
# Run 2, Trial 29: num_city=10, bound=(-100, 100), start_position=25880791
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_30\BeamSplitter.txt
# Run 2, Trial 30: num_city=10, bound=(-100, 100), start_position=54326957
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_11\BeamSplitter.txt
# Run 3, Trial 11: num_city=10, bound=(-100, 100), start_position=22554358
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_12\BeamSplitter.txt
# Run 3, Trial 12: num_city=10, bound=(-100, 100), start_position=42361633
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_13\BeamSplitter.txt
# Run 3, Trial 13: num_city=10, bound=(-100, 100), start_position=60588523
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_14\BeamSplitter.txt
# Run 3, Trial 14: num_city=10, bound=(-100, 100), start_position=30020224
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_15\BeamSplitter.txt
# Run 3, Trial 15: num_city=10, bound=(-100, 100), start_position=49827510
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_16\BeamSplitter.txt
# Run 3, Trial 16: num_city=10, bound=(-100, 100), start_position=82254851
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_17\BeamSplitter.txt
# Run 3, Trial 17: num_city=10, bound=(-100, 100), start_position=40873857
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_18\BeamSplitter.txt
# Run 3, Trial 18: num_city=10, bound=(-100, 100), start_position=56746509
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_19\BeamSplitter.txt
# Run 3, Trial 19: num_city=10, bound=(-100, 100), start_position=73628284
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_20\BeamSplitter.txt
# Run 3, Trial 20: num_city=10, bound=(-100, 100), start_position=46824098
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_21\BeamSplitter.txt
# Run 3, Trial 21: num_city=10, bound=(-100, 100), start_position=42945079
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_22\BeamSplitter.txt
# Run 3, Trial 22: num_city=10, bound=(-100, 100), start_position=42085681
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_23\BeamSplitter.txt
# Run 3, Trial 23: num_city=10, bound=(-100, 100), start_position=80347810
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_24\BeamSplitter.txt
# Run 3, Trial 24: num_city=10, bound=(-100, 100), start_position=4480446
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_25\BeamSplitter.txt
# Run 3, Trial 25: num_city=10, bound=(-100, 100), start_position=63068085
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_26\BeamSplitter.txt
# Run 3, Trial 26: num_city=10, bound=(-100, 100), start_position=53885212
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_27\BeamSplitter.txt
# Run 3, Trial 27: num_city=10, bound=(-100, 100), start_position=61605279
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_28\BeamSplitter.txt
# Run 3, Trial 28: num_city=10, bound=(-100, 100), start_position=53049605
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_29\BeamSplitter.txt
# Run 3, Trial 29: num_city=10, bound=(-100, 100), start_position=26066594
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_30\BeamSplitter.txt
# Run 3, Trial 30: num_city=10, bound=(-100, 100), start_position=18435235
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_11\BeamSplitter.txt
# Run 4, Trial 11: num_city=10, bound=(-100, 100), start_position=52482800
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_12\BeamSplitter.txt
# Run 4, Trial 12: num_city=10, bound=(-100, 100), start_position=14162321
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_13\BeamSplitter.txt
# Run 4, Trial 13: num_city=10, bound=(-100, 100), start_position=55104345
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_14\BeamSplitter.txt
# Run 4, Trial 14: num_city=10, bound=(-100, 100), start_position=32514949
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_15\BeamSplitter.txt
# Run 4, Trial 15: num_city=10, bound=(-100, 100), start_position=21928339
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_16\BeamSplitter.txt
# Run 4, Trial 16: num_city=10, bound=(-100, 100), start_position=75799555
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_17\BeamSplitter.txt
# Run 4, Trial 17: num_city=10, bound=(-100, 100), start_position=56725330
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_18\BeamSplitter.txt
# Run 4, Trial 18: num_city=10, bound=(-100, 100), start_position=20132081
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_19\BeamSplitter.txt
# Run 4, Trial 19: num_city=10, bound=(-100, 100), start_position=74640571
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_20\BeamSplitter.txt
# Run 4, Trial 20: num_city=10, bound=(-100, 100), start_position=27615169
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_21\BeamSplitter.txt
# Run 4, Trial 21: num_city=10, bound=(-100, 100), start_position=81810518
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_22\BeamSplitter.txt
# Run 4, Trial 22: num_city=10, bound=(-100, 100), start_position=58251055
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_23\BeamSplitter.txt
# Run 4, Trial 23: num_city=10, bound=(-100, 100), start_position=58547574
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_24\BeamSplitter.txt
# Run 4, Trial 24: num_city=10, bound=(-100, 100), start_position=894703
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_25\BeamSplitter.txt
# Run 4, Trial 25: num_city=10, bound=(-100, 100), start_position=63359805
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_26\BeamSplitter.txt
# Run 4, Trial 26: num_city=10, bound=(-100, 100), start_position=37326943
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_27\BeamSplitter.txt
# Run 4, Trial 27: num_city=10, bound=(-100, 100), start_position=60028048
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_28\BeamSplitter.txt
# Run 4, Trial 28: num_city=10, bound=(-100, 100), start_position=10938106
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_29\BeamSplitter.txt
# Run 4, Trial 29: num_city=10, bound=(-100, 100), start_position=80631051
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_30\BeamSplitter.txt
# Run 4, Trial 30: num_city=10, bound=(-100, 100), start_position=62807601
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_11\BeamSplitter.txt
# Run 5, Trial 11: num_city=10, bound=(-100, 100), start_position=16219401
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_12\BeamSplitter.txt
# Run 5, Trial 12: num_city=10, bound=(-100, 100), start_position=30445157
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_13\BeamSplitter.txt
# Run 5, Trial 13: num_city=10, bound=(-100, 100), start_position=71845260
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_14\BeamSplitter.txt
# Run 5, Trial 14: num_city=10, bound=(-100, 100), start_position=51161053
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_15\BeamSplitter.txt
# Run 5, Trial 15: num_city=10, bound=(-100, 100), start_position=8098487
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_16\BeamSplitter.txt
# Run 5, Trial 16: num_city=10, bound=(-100, 100), start_position=21692015
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_17\BeamSplitter.txt
# Run 5, Trial 17: num_city=10, bound=(-100, 100), start_position=348849
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_18\BeamSplitter.txt
# Run 5, Trial 18: num_city=10, bound=(-100, 100), start_position=42924124
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_19\BeamSplitter.txt
# Run 5, Trial 19: num_city=10, bound=(-100, 100), start_position=73453743
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_20\BeamSplitter.txt
# Run 5, Trial 20: num_city=10, bound=(-100, 100), start_position=55576062
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_21\BeamSplitter.txt
# Run 5, Trial 21: num_city=10, bound=(-100, 100), start_position=32103549
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_22\BeamSplitter.txt
# Run 5, Trial 22: num_city=10, bound=(-100, 100), start_position=40368359
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_23\BeamSplitter.txt
# Run 5, Trial 23: num_city=10, bound=(-100, 100), start_position=77419264
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_24\BeamSplitter.txt
# Run 5, Trial 24: num_city=10, bound=(-100, 100), start_position=33641022
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_25\BeamSplitter.txt
# Run 5, Trial 25: num_city=10, bound=(-100, 100), start_position=28606987
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_26\BeamSplitter.txt
# Run 5, Trial 26: num_city=10, bound=(-100, 100), start_position=70850426
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_27\BeamSplitter.txt
# Run 5, Trial 27: num_city=10, bound=(-100, 100), start_position=77847119
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_28\BeamSplitter.txt
# Run 5, Trial 28: num_city=10, bound=(-100, 100), start_position=16423294
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_29\BeamSplitter.txt
# Run 5, Trial 29: num_city=10, bound=(-100, 100), start_position=40483128
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_30\BeamSplitter.txt
# Run 5, Trial 30: num_city=10, bound=(-100, 100), start_position=75267665
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_11\BeamSplitter.txt
# Run 6, Trial 11: num_city=10, bound=(-100, 100), start_position=51722914
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_12\BeamSplitter.txt
# Run 6, Trial 12: num_city=10, bound=(-100, 100), start_position=4343489
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_13\BeamSplitter.txt
# Run 6, Trial 13: num_city=10, bound=(-100, 100), start_position=53117590
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_14\BeamSplitter.txt
# Run 6, Trial 14: num_city=10, bound=(-100, 100), start_position=66797076
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_15\BeamSplitter.txt
# Run 6, Trial 15: num_city=10, bound=(-100, 100), start_position=37747165
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_16\BeamSplitter.txt
# Run 6, Trial 16: num_city=10, bound=(-100, 100), start_position=27947786
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_17\BeamSplitter.txt
# Run 6, Trial 17: num_city=10, bound=(-100, 100), start_position=64420835
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_18\BeamSplitter.txt
# Run 6, Trial 18: num_city=10, bound=(-100, 100), start_position=25186070
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_19\BeamSplitter.txt
# Run 6, Trial 19: num_city=10, bound=(-100, 100), start_position=81770227
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_20\BeamSplitter.txt
# Run 6, Trial 20: num_city=10, bound=(-100, 100), start_position=27307862
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_21\BeamSplitter.txt
# Run 6, Trial 21: num_city=10, bound=(-100, 100), start_position=2681603
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_22\BeamSplitter.txt
# Run 6, Trial 22: num_city=10, bound=(-100, 100), start_position=6552588
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_23\BeamSplitter.txt
# Run 6, Trial 23: num_city=10, bound=(-100, 100), start_position=52247302
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_24\BeamSplitter.txt
# Run 6, Trial 24: num_city=10, bound=(-100, 100), start_position=23333541
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_25\BeamSplitter.txt
# Run 6, Trial 25: num_city=10, bound=(-100, 100), start_position=20314178
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_26\BeamSplitter.txt
# Run 6, Trial 26: num_city=10, bound=(-100, 100), start_position=48118649
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_27\BeamSplitter.txt
# Run 6, Trial 27: num_city=10, bound=(-100, 100), start_position=59007889
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_28\BeamSplitter.txt
# Run 6, Trial 28: num_city=10, bound=(-100, 100), start_position=19089622
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_29\BeamSplitter.txt
# Run 6, Trial 29: num_city=10, bound=(-100, 100), start_position=81685640
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_30\BeamSplitter.txt
# Run 6, Trial 30: num_city=10, bound=(-100, 100), start_position=17465897
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_11\BeamSplitter.txt
# Run 7, Trial 11: num_city=10, bound=(-100, 100), start_position=63396554
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_12\BeamSplitter.txt
# Run 7, Trial 12: num_city=10, bound=(-100, 100), start_position=61375893
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_13\BeamSplitter.txt
# Run 7, Trial 13: num_city=10, bound=(-100, 100), start_position=74198707
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_14\BeamSplitter.txt
# Run 7, Trial 14: num_city=10, bound=(-100, 100), start_position=19340313
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_15\BeamSplitter.txt
# Run 7, Trial 15: num_city=10, bound=(-100, 100), start_position=62204690
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_16\BeamSplitter.txt
# Run 7, Trial 16: num_city=10, bound=(-100, 100), start_position=55128459
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_17\BeamSplitter.txt
# Run 7, Trial 17: num_city=10, bound=(-100, 100), start_position=23756978
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_18\BeamSplitter.txt
# Run 7, Trial 18: num_city=10, bound=(-100, 100), start_position=79923113
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_19\BeamSplitter.txt
# Run 7, Trial 19: num_city=10, bound=(-100, 100), start_position=28621261
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_20\BeamSplitter.txt
# Run 7, Trial 20: num_city=10, bound=(-100, 100), start_position=80720945
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_21\BeamSplitter.txt
# Run 7, Trial 21: num_city=10, bound=(-100, 100), start_position=22556147
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_22\BeamSplitter.txt
# Run 7, Trial 22: num_city=10, bound=(-100, 100), start_position=77879396
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_23\BeamSplitter.txt
# Run 7, Trial 23: num_city=10, bound=(-100, 100), start_position=61563626
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_24\BeamSplitter.txt
# Run 7, Trial 24: num_city=10, bound=(-100, 100), start_position=6630319
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_25\BeamSplitter.txt
# Run 7, Trial 25: num_city=10, bound=(-100, 100), start_position=40029168
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_26\BeamSplitter.txt
# Run 7, Trial 26: num_city=10, bound=(-100, 100), start_position=57081145
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_27\BeamSplitter.txt
# Run 7, Trial 27: num_city=10, bound=(-100, 100), start_position=423351
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_28\BeamSplitter.txt
# Run 7, Trial 28: num_city=10, bound=(-100, 100), start_position=24275170
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_29\BeamSplitter.txt
# Run 7, Trial 29: num_city=10, bound=(-100, 100), start_position=76544295
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_30\BeamSplitter.txt
# Run 7, Trial 30: num_city=10, bound=(-100, 100), start_position=76196320
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_11\BeamSplitter.txt
# Run 8, Trial 11: num_city=10, bound=(-100, 100), start_position=66413574
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_12\BeamSplitter.txt
# Run 8, Trial 12: num_city=10, bound=(-100, 100), start_position=23508166
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_13\BeamSplitter.txt
# Run 8, Trial 13: num_city=10, bound=(-100, 100), start_position=37992912
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_14\BeamSplitter.txt
# Run 8, Trial 14: num_city=10, bound=(-100, 100), start_position=4343880
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_15\BeamSplitter.txt
# Run 8, Trial 15: num_city=10, bound=(-100, 100), start_position=47345547
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_16\BeamSplitter.txt
# Run 8, Trial 16: num_city=10, bound=(-100, 100), start_position=12555853
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_17\BeamSplitter.txt
# Run 8, Trial 17: num_city=10, bound=(-100, 100), start_position=78855730
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_18\BeamSplitter.txt
# Run 8, Trial 18: num_city=10, bound=(-100, 100), start_position=15046976
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_19\BeamSplitter.txt
# Run 8, Trial 19: num_city=10, bound=(-100, 100), start_position=27022160
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_20\BeamSplitter.txt
# Run 8, Trial 20: num_city=10, bound=(-100, 100), start_position=46725458
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_21\BeamSplitter.txt
# Run 8, Trial 21: num_city=10, bound=(-100, 100), start_position=74275478
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_22\BeamSplitter.txt
# Run 8, Trial 22: num_city=10, bound=(-100, 100), start_position=29768288
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_23\BeamSplitter.txt
# Run 8, Trial 23: num_city=10, bound=(-100, 100), start_position=40190522
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_24\BeamSplitter.txt
# Run 8, Trial 24: num_city=10, bound=(-100, 100), start_position=13640593
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_25\BeamSplitter.txt
# Run 8, Trial 25: num_city=10, bound=(-100, 100), start_position=15931565
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_26\BeamSplitter.txt
# Run 8, Trial 26: num_city=10, bound=(-100, 100), start_position=4908362
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_27\BeamSplitter.txt
# Run 8, Trial 27: num_city=10, bound=(-100, 100), start_position=45746027
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_28\BeamSplitter.txt
# Run 8, Trial 28: num_city=10, bound=(-100, 100), start_position=80866237
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_29\BeamSplitter.txt
# Run 8, Trial 29: num_city=10, bound=(-100, 100), start_position=40744345
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_30\BeamSplitter.txt
# Run 8, Trial 30: num_city=10, bound=(-100, 100), start_position=29879566
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_11\BeamSplitter.txt
# Run 9, Trial 11: num_city=10, bound=(-100, 100), start_position=81031711
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_12\BeamSplitter.txt
# Run 9, Trial 12: num_city=10, bound=(-100, 100), start_position=36409318
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_13\BeamSplitter.txt
# Run 9, Trial 13: num_city=10, bound=(-100, 100), start_position=63720514
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_14\BeamSplitter.txt
# Run 9, Trial 14: num_city=10, bound=(-100, 100), start_position=19469246
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_15\BeamSplitter.txt
# Run 9, Trial 15: num_city=10, bound=(-100, 100), start_position=49594030
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_16\BeamSplitter.txt
# Run 9, Trial 16: num_city=10, bound=(-100, 100), start_position=79427141
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_17\BeamSplitter.txt
# Run 9, Trial 17: num_city=10, bound=(-100, 100), start_position=69998697
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_18\BeamSplitter.txt
# Run 9, Trial 18: num_city=10, bound=(-100, 100), start_position=54458620
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_19\BeamSplitter.txt
# Run 9, Trial 19: num_city=10, bound=(-100, 100), start_position=32025161
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_20\BeamSplitter.txt
# Run 9, Trial 20: num_city=10, bound=(-100, 100), start_position=1951697
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_21\BeamSplitter.txt
# Run 9, Trial 21: num_city=10, bound=(-100, 100), start_position=23362576
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_22\BeamSplitter.txt
# Run 9, Trial 22: num_city=10, bound=(-100, 100), start_position=7237571
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_23\BeamSplitter.txt
# Run 9, Trial 23: num_city=10, bound=(-100, 100), start_position=65218530
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_24\BeamSplitter.txt
# Run 9, Trial 24: num_city=10, bound=(-100, 100), start_position=54146334
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_25\BeamSplitter.txt
# Run 9, Trial 25: num_city=10, bound=(-100, 100), start_position=77850012
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_26\BeamSplitter.txt
# Run 9, Trial 26: num_city=10, bound=(-100, 100), start_position=24824099
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_27\BeamSplitter.txt
# Run 9, Trial 27: num_city=10, bound=(-100, 100), start_position=44947058
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_28\BeamSplitter.txt
# Run 9, Trial 28: num_city=10, bound=(-100, 100), start_position=35525636
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_29\BeamSplitter.txt
# Run 9, Trial 29: num_city=10, bound=(-100, 100), start_position=60389858
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_30\BeamSplitter.txt
# Run 9, Trial 30: num_city=10, bound=(-100, 100), start_position=10077606
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_11\BeamSplitter.txt
# Run 10, Trial 11: num_city=10, bound=(-100, 100), start_position=65940900
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_12\BeamSplitter.txt
# Run 10, Trial 12: num_city=10, bound=(-100, 100), start_position=36694262
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_13\BeamSplitter.txt
# Run 10, Trial 13: num_city=10, bound=(-100, 100), start_position=53674212
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_14\BeamSplitter.txt
# Run 10, Trial 14: num_city=10, bound=(-100, 100), start_position=12932199
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_15\BeamSplitter.txt
# Run 10, Trial 15: num_city=10, bound=(-100, 100), start_position=19399820
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_16\BeamSplitter.txt
# Run 10, Trial 16: num_city=10, bound=(-100, 100), start_position=42525600
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_17\BeamSplitter.txt
# Run 10, Trial 17: num_city=10, bound=(-100, 100), start_position=12771677
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_18\BeamSplitter.txt
# Run 10, Trial 18: num_city=10, bound=(-100, 100), start_position=56739908
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_19\BeamSplitter.txt
# Run 10, Trial 19: num_city=10, bound=(-100, 100), start_position=34927455
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_20\BeamSplitter.txt
# Run 10, Trial 20: num_city=10, bound=(-100, 100), start_position=27106990
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_21\BeamSplitter.txt
# Run 10, Trial 21: num_city=10, bound=(-100, 100), start_position=73410040
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_22\BeamSplitter.txt
# Run 10, Trial 22: num_city=10, bound=(-100, 100), start_position=51341549
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_23\BeamSplitter.txt
# Run 10, Trial 23: num_city=10, bound=(-100, 100), start_position=5561714
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_24\BeamSplitter.txt
# Run 10, Trial 24: num_city=10, bound=(-100, 100), start_position=40935610
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_25\BeamSplitter.txt
# Run 10, Trial 25: num_city=10, bound=(-100, 100), start_position=40422578
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_26\BeamSplitter.txt
# Run 10, Trial 26: num_city=10, bound=(-100, 100), start_position=14774292
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_27\BeamSplitter.txt
# Run 10, Trial 27: num_city=10, bound=(-100, 100), start_position=15429312
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_28\BeamSplitter.txt
# Run 10, Trial 28: num_city=10, bound=(-100, 100), start_position=56449598
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_29\BeamSplitter.txt
# Run 10, Trial 29: num_city=10, bound=(-100, 100), start_position=31366236
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_30\BeamSplitter.txt
# Run 10, Trial 30: num_city=10, bound=(-100, 100), start_position=77389610

# %%
# Run the process 10 times, each with a different num_city value and saving in a new location
for run_index in range(1, 11):  # 10 separate runs
    num_city, bound = input_sets[run_index - 1]  # Get num_city and bound from the input set
    
    # Define the **run-specific** directory (F12021, F22021, ..., F102021)
    base_output_dir = os.path.join("starting_solution", "CEC2021", f"F{run_index}2021")
    os.makedirs(base_output_dir, exist_ok=True)  # Ensure the base directory exists
    
    # Run 10 trials per run
    for trial_index in range(11, num_trials + 1):  
        # Define the subdirectory for each trial
        trial_dir = os.path.join(base_output_dir, f"trial_{trial_index}")
        os.makedirs(trial_dir, exist_ok=True)  # Ensure the trial directory exists
        
        # Define the file path
        output_file_path = os.path.join(trial_dir, "Ibm.txt")

        # Process the normalization data and save to the file
        start = process_normalization_f12021_data(
            data=Ibm, 
            num_city=num_city, 
            pop_size=100, 
            file_path=output_file_path, 
            bound=bound
        )

        # Print the expected output format
        print(f"Run {run_index}, Trial {trial_index}: num_city={num_city}, bound={bound}, start_position={start}")
# Out:
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_11\Ibm.txt
# Run 1, Trial 11: num_city=10, bound=(-100, 100), start_position=36970495
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_12\Ibm.txt
# Run 1, Trial 12: num_city=10, bound=(-100, 100), start_position=77320812
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_13\Ibm.txt
# Run 1, Trial 13: num_city=10, bound=(-100, 100), start_position=22849128
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_14\Ibm.txt
# Run 1, Trial 14: num_city=10, bound=(-100, 100), start_position=75899533
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_15\Ibm.txt
# Run 1, Trial 15: num_city=10, bound=(-100, 100), start_position=43528435
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_16\Ibm.txt
# Run 1, Trial 16: num_city=10, bound=(-100, 100), start_position=33730143
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_17\Ibm.txt
# Run 1, Trial 17: num_city=10, bound=(-100, 100), start_position=47772524
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_18\Ibm.txt
# Run 1, Trial 18: num_city=10, bound=(-100, 100), start_position=29713880
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_19\Ibm.txt
# Run 1, Trial 19: num_city=10, bound=(-100, 100), start_position=51149778
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_20\Ibm.txt
# Run 1, Trial 20: num_city=10, bound=(-100, 100), start_position=64862929
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_21\Ibm.txt
# Run 1, Trial 21: num_city=10, bound=(-100, 100), start_position=15479683
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_22\Ibm.txt
# Run 1, Trial 22: num_city=10, bound=(-100, 100), start_position=53626045
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_23\Ibm.txt
# Run 1, Trial 23: num_city=10, bound=(-100, 100), start_position=4113333
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_24\Ibm.txt
# Run 1, Trial 24: num_city=10, bound=(-100, 100), start_position=55357477
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_25\Ibm.txt
# Run 1, Trial 25: num_city=10, bound=(-100, 100), start_position=24774866
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_26\Ibm.txt
# Run 1, Trial 26: num_city=10, bound=(-100, 100), start_position=59021862
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_27\Ibm.txt
# Run 1, Trial 27: num_city=10, bound=(-100, 100), start_position=55171614
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_28\Ibm.txt
# Run 1, Trial 28: num_city=10, bound=(-100, 100), start_position=62532170
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_29\Ibm.txt
# Run 1, Trial 29: num_city=10, bound=(-100, 100), start_position=23652467
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_30\Ibm.txt
# Run 1, Trial 30: num_city=10, bound=(-100, 100), start_position=31823786
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_11\Ibm.txt
# Run 2, Trial 11: num_city=10, bound=(-100, 100), start_position=66908188
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_12\Ibm.txt
# Run 2, Trial 12: num_city=10, bound=(-100, 100), start_position=33420155
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_13\Ibm.txt
# Run 2, Trial 13: num_city=10, bound=(-100, 100), start_position=7380882
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_14\Ibm.txt
# Run 2, Trial 14: num_city=10, bound=(-100, 100), start_position=2731724
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_15\Ibm.txt
# Run 2, Trial 15: num_city=10, bound=(-100, 100), start_position=22434510
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_16\Ibm.txt
# Run 2, Trial 16: num_city=10, bound=(-100, 100), start_position=67894015
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_17\Ibm.txt
# Run 2, Trial 17: num_city=10, bound=(-100, 100), start_position=40565357
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_18\Ibm.txt
# Run 2, Trial 18: num_city=10, bound=(-100, 100), start_position=4039043
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_19\Ibm.txt
# Run 2, Trial 19: num_city=10, bound=(-100, 100), start_position=7954180
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_20\Ibm.txt
# Run 2, Trial 20: num_city=10, bound=(-100, 100), start_position=62194924
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_21\Ibm.txt
# Run 2, Trial 21: num_city=10, bound=(-100, 100), start_position=22573044
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_22\Ibm.txt
# Run 2, Trial 22: num_city=10, bound=(-100, 100), start_position=11546273
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_23\Ibm.txt
# Run 2, Trial 23: num_city=10, bound=(-100, 100), start_position=29578050
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_24\Ibm.txt
# Run 2, Trial 24: num_city=10, bound=(-100, 100), start_position=67520644
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_25\Ibm.txt
# Run 2, Trial 25: num_city=10, bound=(-100, 100), start_position=4289958
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_26\Ibm.txt
# Run 2, Trial 26: num_city=10, bound=(-100, 100), start_position=33733950
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_27\Ibm.txt
# Run 2, Trial 27: num_city=10, bound=(-100, 100), start_position=44946360
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_28\Ibm.txt
# Run 2, Trial 28: num_city=10, bound=(-100, 100), start_position=12633342
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_29\Ibm.txt
# Run 2, Trial 29: num_city=10, bound=(-100, 100), start_position=76225976
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_30\Ibm.txt
# Run 2, Trial 30: num_city=10, bound=(-100, 100), start_position=55263270
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_11\Ibm.txt
# Run 3, Trial 11: num_city=10, bound=(-100, 100), start_position=40769001
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_12\Ibm.txt
# Run 3, Trial 12: num_city=10, bound=(-100, 100), start_position=72033473
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_13\Ibm.txt
# Run 3, Trial 13: num_city=10, bound=(-100, 100), start_position=44248916
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_14\Ibm.txt
# Run 3, Trial 14: num_city=10, bound=(-100, 100), start_position=4535301
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_15\Ibm.txt
# Run 3, Trial 15: num_city=10, bound=(-100, 100), start_position=65053552
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_16\Ibm.txt
# Run 3, Trial 16: num_city=10, bound=(-100, 100), start_position=8353828
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_17\Ibm.txt
# Run 3, Trial 17: num_city=10, bound=(-100, 100), start_position=60618919
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_18\Ibm.txt
# Run 3, Trial 18: num_city=10, bound=(-100, 100), start_position=80910342
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_19\Ibm.txt
# Run 3, Trial 19: num_city=10, bound=(-100, 100), start_position=12515315
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_20\Ibm.txt
# Run 3, Trial 20: num_city=10, bound=(-100, 100), start_position=17587924
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_21\Ibm.txt
# Run 3, Trial 21: num_city=10, bound=(-100, 100), start_position=24215837
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_22\Ibm.txt
# Run 3, Trial 22: num_city=10, bound=(-100, 100), start_position=38808371
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_23\Ibm.txt
# Run 3, Trial 23: num_city=10, bound=(-100, 100), start_position=26886440
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_24\Ibm.txt
# Run 3, Trial 24: num_city=10, bound=(-100, 100), start_position=22856343
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_25\Ibm.txt
# Run 3, Trial 25: num_city=10, bound=(-100, 100), start_position=70158028
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_26\Ibm.txt
# Run 3, Trial 26: num_city=10, bound=(-100, 100), start_position=45652480
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_27\Ibm.txt
# Run 3, Trial 27: num_city=10, bound=(-100, 100), start_position=36678400
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_28\Ibm.txt
# Run 3, Trial 28: num_city=10, bound=(-100, 100), start_position=11470555
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_29\Ibm.txt
# Run 3, Trial 29: num_city=10, bound=(-100, 100), start_position=75343818
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_30\Ibm.txt
# Run 3, Trial 30: num_city=10, bound=(-100, 100), start_position=78229955
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_11\Ibm.txt
# Run 4, Trial 11: num_city=10, bound=(-100, 100), start_position=17040461
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_12\Ibm.txt
# Run 4, Trial 12: num_city=10, bound=(-100, 100), start_position=63212892
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_13\Ibm.txt
# Run 4, Trial 13: num_city=10, bound=(-100, 100), start_position=54673261
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_14\Ibm.txt
# Run 4, Trial 14: num_city=10, bound=(-100, 100), start_position=12387723
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_15\Ibm.txt
# Run 4, Trial 15: num_city=10, bound=(-100, 100), start_position=23314534
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_16\Ibm.txt
# Run 4, Trial 16: num_city=10, bound=(-100, 100), start_position=54870841
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_17\Ibm.txt
# Run 4, Trial 17: num_city=10, bound=(-100, 100), start_position=35722663
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_18\Ibm.txt
# Run 4, Trial 18: num_city=10, bound=(-100, 100), start_position=2689558
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_19\Ibm.txt
# Run 4, Trial 19: num_city=10, bound=(-100, 100), start_position=75087347
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_20\Ibm.txt
# Run 4, Trial 20: num_city=10, bound=(-100, 100), start_position=40770265
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_21\Ibm.txt
# Run 4, Trial 21: num_city=10, bound=(-100, 100), start_position=13653497
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_22\Ibm.txt
# Run 4, Trial 22: num_city=10, bound=(-100, 100), start_position=43841713
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_23\Ibm.txt
# Run 4, Trial 23: num_city=10, bound=(-100, 100), start_position=63200058
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_24\Ibm.txt
# Run 4, Trial 24: num_city=10, bound=(-100, 100), start_position=79317810
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_25\Ibm.txt
# Run 4, Trial 25: num_city=10, bound=(-100, 100), start_position=31702183
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_26\Ibm.txt
# Run 4, Trial 26: num_city=10, bound=(-100, 100), start_position=70570711
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_27\Ibm.txt
# Run 4, Trial 27: num_city=10, bound=(-100, 100), start_position=23568129
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_28\Ibm.txt
# Run 4, Trial 28: num_city=10, bound=(-100, 100), start_position=73226371
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_29\Ibm.txt
# Run 4, Trial 29: num_city=10, bound=(-100, 100), start_position=64037795
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_30\Ibm.txt
# Run 4, Trial 30: num_city=10, bound=(-100, 100), start_position=36819193
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_11\Ibm.txt
# Run 5, Trial 11: num_city=10, bound=(-100, 100), start_position=33288304
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_12\Ibm.txt
# Run 5, Trial 12: num_city=10, bound=(-100, 100), start_position=17009242
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_13\Ibm.txt
# Run 5, Trial 13: num_city=10, bound=(-100, 100), start_position=43888650
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_14\Ibm.txt
# Run 5, Trial 14: num_city=10, bound=(-100, 100), start_position=28108344
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_15\Ibm.txt
# Run 5, Trial 15: num_city=10, bound=(-100, 100), start_position=63874066
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_16\Ibm.txt
# Run 5, Trial 16: num_city=10, bound=(-100, 100), start_position=54514530
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_17\Ibm.txt
# Run 5, Trial 17: num_city=10, bound=(-100, 100), start_position=35187751
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_18\Ibm.txt
# Run 5, Trial 18: num_city=10, bound=(-100, 100), start_position=59960810
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_19\Ibm.txt
# Run 5, Trial 19: num_city=10, bound=(-100, 100), start_position=43958096
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_20\Ibm.txt
# Run 5, Trial 20: num_city=10, bound=(-100, 100), start_position=42555633
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_21\Ibm.txt
# Run 5, Trial 21: num_city=10, bound=(-100, 100), start_position=41788350
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_22\Ibm.txt
# Run 5, Trial 22: num_city=10, bound=(-100, 100), start_position=20500410
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_23\Ibm.txt
# Run 5, Trial 23: num_city=10, bound=(-100, 100), start_position=15038611
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_24\Ibm.txt
# Run 5, Trial 24: num_city=10, bound=(-100, 100), start_position=3867430
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_25\Ibm.txt
# Run 5, Trial 25: num_city=10, bound=(-100, 100), start_position=22977114
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_26\Ibm.txt
# Run 5, Trial 26: num_city=10, bound=(-100, 100), start_position=65899705
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_27\Ibm.txt
# Run 5, Trial 27: num_city=10, bound=(-100, 100), start_position=7664459
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_28\Ibm.txt
# Run 5, Trial 28: num_city=10, bound=(-100, 100), start_position=17089419
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_29\Ibm.txt
# Run 5, Trial 29: num_city=10, bound=(-100, 100), start_position=22351130
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_30\Ibm.txt
# Run 5, Trial 30: num_city=10, bound=(-100, 100), start_position=54081387
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_11\Ibm.txt
# Run 6, Trial 11: num_city=10, bound=(-100, 100), start_position=7079944
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_12\Ibm.txt
# Run 6, Trial 12: num_city=10, bound=(-100, 100), start_position=43111782
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_13\Ibm.txt
# Run 6, Trial 13: num_city=10, bound=(-100, 100), start_position=54766584
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_14\Ibm.txt
# Run 6, Trial 14: num_city=10, bound=(-100, 100), start_position=82259299
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_15\Ibm.txt
# Run 6, Trial 15: num_city=10, bound=(-100, 100), start_position=11086702
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_16\Ibm.txt
# Run 6, Trial 16: num_city=10, bound=(-100, 100), start_position=46262310
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_17\Ibm.txt
# Run 6, Trial 17: num_city=10, bound=(-100, 100), start_position=55287711
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_18\Ibm.txt
# Run 6, Trial 18: num_city=10, bound=(-100, 100), start_position=6976257
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_19\Ibm.txt
# Run 6, Trial 19: num_city=10, bound=(-100, 100), start_position=73507603
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_20\Ibm.txt
# Run 6, Trial 20: num_city=10, bound=(-100, 100), start_position=25834405
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_21\Ibm.txt
# Run 6, Trial 21: num_city=10, bound=(-100, 100), start_position=39768502
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_22\Ibm.txt
# Run 6, Trial 22: num_city=10, bound=(-100, 100), start_position=51084818
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_23\Ibm.txt
# Run 6, Trial 23: num_city=10, bound=(-100, 100), start_position=4100891
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_24\Ibm.txt
# Run 6, Trial 24: num_city=10, bound=(-100, 100), start_position=62535808
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_25\Ibm.txt
# Run 6, Trial 25: num_city=10, bound=(-100, 100), start_position=31410115
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_26\Ibm.txt
# Run 6, Trial 26: num_city=10, bound=(-100, 100), start_position=59777685
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_27\Ibm.txt
# Run 6, Trial 27: num_city=10, bound=(-100, 100), start_position=6266300
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_28\Ibm.txt
# Run 6, Trial 28: num_city=10, bound=(-100, 100), start_position=58945511
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_29\Ibm.txt
# Run 6, Trial 29: num_city=10, bound=(-100, 100), start_position=21983732
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_30\Ibm.txt
# Run 6, Trial 30: num_city=10, bound=(-100, 100), start_position=30108139
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_11\Ibm.txt
# Run 7, Trial 11: num_city=10, bound=(-100, 100), start_position=23652257
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_12\Ibm.txt
# Run 7, Trial 12: num_city=10, bound=(-100, 100), start_position=50384785
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_13\Ibm.txt
# Run 7, Trial 13: num_city=10, bound=(-100, 100), start_position=5109192
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_14\Ibm.txt
# Run 7, Trial 14: num_city=10, bound=(-100, 100), start_position=6325906
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_15\Ibm.txt
# Run 7, Trial 15: num_city=10, bound=(-100, 100), start_position=38237996
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_16\Ibm.txt
# Run 7, Trial 16: num_city=10, bound=(-100, 100), start_position=27021567
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_17\Ibm.txt
# Run 7, Trial 17: num_city=10, bound=(-100, 100), start_position=66832666
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_18\Ibm.txt
# Run 7, Trial 18: num_city=10, bound=(-100, 100), start_position=43271484
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_19\Ibm.txt
# Run 7, Trial 19: num_city=10, bound=(-100, 100), start_position=59258393
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_20\Ibm.txt
# Run 7, Trial 20: num_city=10, bound=(-100, 100), start_position=48931893
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_21\Ibm.txt
# Run 7, Trial 21: num_city=10, bound=(-100, 100), start_position=35477286
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_22\Ibm.txt
# Run 7, Trial 22: num_city=10, bound=(-100, 100), start_position=35944713
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_23\Ibm.txt
# Run 7, Trial 23: num_city=10, bound=(-100, 100), start_position=10878345
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_24\Ibm.txt
# Run 7, Trial 24: num_city=10, bound=(-100, 100), start_position=17865176
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_25\Ibm.txt
# Run 7, Trial 25: num_city=10, bound=(-100, 100), start_position=82187448
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_26\Ibm.txt
# Run 7, Trial 26: num_city=10, bound=(-100, 100), start_position=57212788
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_27\Ibm.txt
# Run 7, Trial 27: num_city=10, bound=(-100, 100), start_position=47659927
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_28\Ibm.txt
# Run 7, Trial 28: num_city=10, bound=(-100, 100), start_position=27073241
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_29\Ibm.txt
# Run 7, Trial 29: num_city=10, bound=(-100, 100), start_position=56731124
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_30\Ibm.txt
# Run 7, Trial 30: num_city=10, bound=(-100, 100), start_position=30761263
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_11\Ibm.txt
# Run 8, Trial 11: num_city=10, bound=(-100, 100), start_position=39214580
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_12\Ibm.txt
# Run 8, Trial 12: num_city=10, bound=(-100, 100), start_position=10230972
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_13\Ibm.txt
# Run 8, Trial 13: num_city=10, bound=(-100, 100), start_position=64843896
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_14\Ibm.txt
# Run 8, Trial 14: num_city=10, bound=(-100, 100), start_position=43532116
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_15\Ibm.txt
# Run 8, Trial 15: num_city=10, bound=(-100, 100), start_position=74976168
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_16\Ibm.txt
# Run 8, Trial 16: num_city=10, bound=(-100, 100), start_position=41373917
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_17\Ibm.txt
# Run 8, Trial 17: num_city=10, bound=(-100, 100), start_position=26797458
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_18\Ibm.txt
# Run 8, Trial 18: num_city=10, bound=(-100, 100), start_position=20388250
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_19\Ibm.txt
# Run 8, Trial 19: num_city=10, bound=(-100, 100), start_position=8641306
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_20\Ibm.txt
# Run 8, Trial 20: num_city=10, bound=(-100, 100), start_position=62104521
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_21\Ibm.txt
# Run 8, Trial 21: num_city=10, bound=(-100, 100), start_position=66523107
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_22\Ibm.txt
# Run 8, Trial 22: num_city=10, bound=(-100, 100), start_position=20831514
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_23\Ibm.txt
# Run 8, Trial 23: num_city=10, bound=(-100, 100), start_position=61419233
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_24\Ibm.txt
# Run 8, Trial 24: num_city=10, bound=(-100, 100), start_position=73626038
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_25\Ibm.txt
# Run 8, Trial 25: num_city=10, bound=(-100, 100), start_position=77903750
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_26\Ibm.txt
# Run 8, Trial 26: num_city=10, bound=(-100, 100), start_position=66026102
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_27\Ibm.txt
# Run 8, Trial 27: num_city=10, bound=(-100, 100), start_position=42435158
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_28\Ibm.txt
# Run 8, Trial 28: num_city=10, bound=(-100, 100), start_position=19203463
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_29\Ibm.txt
# Run 8, Trial 29: num_city=10, bound=(-100, 100), start_position=61041749
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_30\Ibm.txt
# Run 8, Trial 30: num_city=10, bound=(-100, 100), start_position=11171386
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_11\Ibm.txt
# Run 9, Trial 11: num_city=10, bound=(-100, 100), start_position=68999682
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_12\Ibm.txt
# Run 9, Trial 12: num_city=10, bound=(-100, 100), start_position=45632414
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_13\Ibm.txt
# Run 9, Trial 13: num_city=10, bound=(-100, 100), start_position=56693693
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_14\Ibm.txt
# Run 9, Trial 14: num_city=10, bound=(-100, 100), start_position=75287408
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_15\Ibm.txt
# Run 9, Trial 15: num_city=10, bound=(-100, 100), start_position=51879951
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_16\Ibm.txt
# Run 9, Trial 16: num_city=10, bound=(-100, 100), start_position=67988188
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_17\Ibm.txt
# Run 9, Trial 17: num_city=10, bound=(-100, 100), start_position=39605489
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_18\Ibm.txt
# Run 9, Trial 18: num_city=10, bound=(-100, 100), start_position=70921200
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_19\Ibm.txt
# Run 9, Trial 19: num_city=10, bound=(-100, 100), start_position=47726686
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_20\Ibm.txt
# Run 9, Trial 20: num_city=10, bound=(-100, 100), start_position=80266619
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_21\Ibm.txt
# Run 9, Trial 21: num_city=10, bound=(-100, 100), start_position=63716460
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_22\Ibm.txt
# Run 9, Trial 22: num_city=10, bound=(-100, 100), start_position=23415572
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_23\Ibm.txt
# Run 9, Trial 23: num_city=10, bound=(-100, 100), start_position=61409188
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_24\Ibm.txt
# Run 9, Trial 24: num_city=10, bound=(-100, 100), start_position=5465128
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_25\Ibm.txt
# Run 9, Trial 25: num_city=10, bound=(-100, 100), start_position=53928545
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_26\Ibm.txt
# Run 9, Trial 26: num_city=10, bound=(-100, 100), start_position=52480771
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_27\Ibm.txt
# Run 9, Trial 27: num_city=10, bound=(-100, 100), start_position=29808598
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_28\Ibm.txt
# Run 9, Trial 28: num_city=10, bound=(-100, 100), start_position=37982013
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_29\Ibm.txt
# Run 9, Trial 29: num_city=10, bound=(-100, 100), start_position=12731502
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_30\Ibm.txt
# Run 9, Trial 30: num_city=10, bound=(-100, 100), start_position=9238127
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_11\Ibm.txt
# Run 10, Trial 11: num_city=10, bound=(-100, 100), start_position=11205920
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_12\Ibm.txt
# Run 10, Trial 12: num_city=10, bound=(-100, 100), start_position=29214467
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_13\Ibm.txt
# Run 10, Trial 13: num_city=10, bound=(-100, 100), start_position=67068515
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_14\Ibm.txt
# Run 10, Trial 14: num_city=10, bound=(-100, 100), start_position=6506685
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_15\Ibm.txt
# Run 10, Trial 15: num_city=10, bound=(-100, 100), start_position=59786802
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_16\Ibm.txt
# Run 10, Trial 16: num_city=10, bound=(-100, 100), start_position=31645291
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_17\Ibm.txt
# Run 10, Trial 17: num_city=10, bound=(-100, 100), start_position=64514918
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_18\Ibm.txt
# Run 10, Trial 18: num_city=10, bound=(-100, 100), start_position=72326727
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_19\Ibm.txt
# Run 10, Trial 19: num_city=10, bound=(-100, 100), start_position=79747498
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_20\Ibm.txt
# Run 10, Trial 20: num_city=10, bound=(-100, 100), start_position=40544649
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_21\Ibm.txt
# Run 10, Trial 21: num_city=10, bound=(-100, 100), start_position=39472911
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_22\Ibm.txt
# Run 10, Trial 22: num_city=10, bound=(-100, 100), start_position=79797964
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_23\Ibm.txt
# Run 10, Trial 23: num_city=10, bound=(-100, 100), start_position=26946589
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_24\Ibm.txt
# Run 10, Trial 24: num_city=10, bound=(-100, 100), start_position=52567414
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_25\Ibm.txt
# Run 10, Trial 25: num_city=10, bound=(-100, 100), start_position=6771137
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_26\Ibm.txt
# Run 10, Trial 26: num_city=10, bound=(-100, 100), start_position=79150149
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_27\Ibm.txt
# Run 10, Trial 27: num_city=10, bound=(-100, 100), start_position=14733694
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_28\Ibm.txt
# Run 10, Trial 28: num_city=10, bound=(-100, 100), start_position=36414571
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_29\Ibm.txt
# Run 10, Trial 29: num_city=10, bound=(-100, 100), start_position=6570224
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_30\Ibm.txt
# Run 10, Trial 30: num_city=10, bound=(-100, 100), start_position=54926483

# %%
# Run the process 10 times, each with a different num_city value and saving in a new location
for run_index in range(1, 11):  # 10 separate runs
    num_city, bound = input_sets[run_index - 1]  # Get num_city and bound from the input set
    
    # Define the **run-specific** directory (F12021, F22021, ..., F102021)
    base_output_dir = os.path.join("starting_solution", "CEC2021", f"F{run_index}2021")
    os.makedirs(base_output_dir, exist_ok=True)  # Ensure the base directory exists
    
    # Run 10 trials per run
    for trial_index in range(11, num_trials + 1):  
        # Define the subdirectory for each trial
        trial_dir = os.path.join(base_output_dir, f"trial_{trial_index}")
        os.makedirs(trial_dir, exist_ok=True)  # Ensure the trial directory exists
        
        # Define the file path
        output_file_path = os.path.join(trial_dir, "QuasiRandom.txt")

        # Process the normalization data and save to the file
        start = process_normalization_f12021_data(
            data=QuasiRandom, 
            num_city=num_city, 
            pop_size=100, 
            file_path=output_file_path, 
            bound=bound
        )

        # Print the expected output format
        print(f"Run {run_index}, Trial {trial_index}: num_city={num_city}, bound={bound}, start_position={start}")
# Out:
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_11\QuasiRandom.txt
# Run 1, Trial 11: num_city=10, bound=(-100, 100), start_position=15261705
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_12\QuasiRandom.txt
# Run 1, Trial 12: num_city=10, bound=(-100, 100), start_position=32582411
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_13\QuasiRandom.txt
# Run 1, Trial 13: num_city=10, bound=(-100, 100), start_position=34114704
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_14\QuasiRandom.txt
# Run 1, Trial 14: num_city=10, bound=(-100, 100), start_position=11571551
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_15\QuasiRandom.txt
# Run 1, Trial 15: num_city=10, bound=(-100, 100), start_position=78891771
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_16\QuasiRandom.txt
# Run 1, Trial 16: num_city=10, bound=(-100, 100), start_position=59550630
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_17\QuasiRandom.txt
# Run 1, Trial 17: num_city=10, bound=(-100, 100), start_position=54074686
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_18\QuasiRandom.txt
# Run 1, Trial 18: num_city=10, bound=(-100, 100), start_position=70581833
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_19\QuasiRandom.txt
# Run 1, Trial 19: num_city=10, bound=(-100, 100), start_position=60392495
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_20\QuasiRandom.txt
# Run 1, Trial 20: num_city=10, bound=(-100, 100), start_position=45854274
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_21\QuasiRandom.txt
# Run 1, Trial 21: num_city=10, bound=(-100, 100), start_position=73101946
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_22\QuasiRandom.txt
# Run 1, Trial 22: num_city=10, bound=(-100, 100), start_position=35888457
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_23\QuasiRandom.txt
# Run 1, Trial 23: num_city=10, bound=(-100, 100), start_position=36820048
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_24\QuasiRandom.txt
# Run 1, Trial 24: num_city=10, bound=(-100, 100), start_position=3835622
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_25\QuasiRandom.txt
# Run 1, Trial 25: num_city=10, bound=(-100, 100), start_position=24569329
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_26\QuasiRandom.txt
# Run 1, Trial 26: num_city=10, bound=(-100, 100), start_position=76338386
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_27\QuasiRandom.txt
# Run 1, Trial 27: num_city=10, bound=(-100, 100), start_position=154547
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_28\QuasiRandom.txt
# Run 1, Trial 28: num_city=10, bound=(-100, 100), start_position=40028648
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_29\QuasiRandom.txt
# Run 1, Trial 29: num_city=10, bound=(-100, 100), start_position=68563387
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_30\QuasiRandom.txt
# Run 1, Trial 30: num_city=10, bound=(-100, 100), start_position=53726985
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_11\QuasiRandom.txt
# Run 2, Trial 11: num_city=10, bound=(-100, 100), start_position=67800901
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_12\QuasiRandom.txt
# Run 2, Trial 12: num_city=10, bound=(-100, 100), start_position=54302593
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_13\QuasiRandom.txt
# Run 2, Trial 13: num_city=10, bound=(-100, 100), start_position=22392057
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_14\QuasiRandom.txt
# Run 2, Trial 14: num_city=10, bound=(-100, 100), start_position=76681570
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_15\QuasiRandom.txt
# Run 2, Trial 15: num_city=10, bound=(-100, 100), start_position=8285797
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_16\QuasiRandom.txt
# Run 2, Trial 16: num_city=10, bound=(-100, 100), start_position=33820
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_17\QuasiRandom.txt
# Run 2, Trial 17: num_city=10, bound=(-100, 100), start_position=81941255
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_18\QuasiRandom.txt
# Run 2, Trial 18: num_city=10, bound=(-100, 100), start_position=42039901
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_19\QuasiRandom.txt
# Run 2, Trial 19: num_city=10, bound=(-100, 100), start_position=20686124
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_20\QuasiRandom.txt
# Run 2, Trial 20: num_city=10, bound=(-100, 100), start_position=81431920
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_21\QuasiRandom.txt
# Run 2, Trial 21: num_city=10, bound=(-100, 100), start_position=16669775
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_22\QuasiRandom.txt
# Run 2, Trial 22: num_city=10, bound=(-100, 100), start_position=43239371
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_23\QuasiRandom.txt
# Run 2, Trial 23: num_city=10, bound=(-100, 100), start_position=47665954
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_24\QuasiRandom.txt
# Run 2, Trial 24: num_city=10, bound=(-100, 100), start_position=33055184
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_25\QuasiRandom.txt
# Run 2, Trial 25: num_city=10, bound=(-100, 100), start_position=37071677
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_26\QuasiRandom.txt
# Run 2, Trial 26: num_city=10, bound=(-100, 100), start_position=32952524
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_27\QuasiRandom.txt
# Run 2, Trial 27: num_city=10, bound=(-100, 100), start_position=68353384
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_28\QuasiRandom.txt
# Run 2, Trial 28: num_city=10, bound=(-100, 100), start_position=24964719
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_29\QuasiRandom.txt
# Run 2, Trial 29: num_city=10, bound=(-100, 100), start_position=20037344
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_30\QuasiRandom.txt
# Run 2, Trial 30: num_city=10, bound=(-100, 100), start_position=67832189
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_11\QuasiRandom.txt
# Run 3, Trial 11: num_city=10, bound=(-100, 100), start_position=18209737
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_12\QuasiRandom.txt
# Run 3, Trial 12: num_city=10, bound=(-100, 100), start_position=44793485
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_13\QuasiRandom.txt
# Run 3, Trial 13: num_city=10, bound=(-100, 100), start_position=40105629
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_14\QuasiRandom.txt
# Run 3, Trial 14: num_city=10, bound=(-100, 100), start_position=11759820
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_15\QuasiRandom.txt
# Run 3, Trial 15: num_city=10, bound=(-100, 100), start_position=17474892
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_16\QuasiRandom.txt
# Run 3, Trial 16: num_city=10, bound=(-100, 100), start_position=43973933
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_17\QuasiRandom.txt
# Run 3, Trial 17: num_city=10, bound=(-100, 100), start_position=62085802
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_18\QuasiRandom.txt
# Run 3, Trial 18: num_city=10, bound=(-100, 100), start_position=16094766
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_19\QuasiRandom.txt
# Run 3, Trial 19: num_city=10, bound=(-100, 100), start_position=43679100
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_20\QuasiRandom.txt
# Run 3, Trial 20: num_city=10, bound=(-100, 100), start_position=63395689
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_21\QuasiRandom.txt
# Run 3, Trial 21: num_city=10, bound=(-100, 100), start_position=66326611
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_22\QuasiRandom.txt
# Run 3, Trial 22: num_city=10, bound=(-100, 100), start_position=79742602
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_23\QuasiRandom.txt
# Run 3, Trial 23: num_city=10, bound=(-100, 100), start_position=76124123
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_24\QuasiRandom.txt
# Run 3, Trial 24: num_city=10, bound=(-100, 100), start_position=39709130
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_25\QuasiRandom.txt
# Run 3, Trial 25: num_city=10, bound=(-100, 100), start_position=17331053
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_26\QuasiRandom.txt
# Run 3, Trial 26: num_city=10, bound=(-100, 100), start_position=51852173
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_27\QuasiRandom.txt
# Run 3, Trial 27: num_city=10, bound=(-100, 100), start_position=62465335
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_28\QuasiRandom.txt
# Run 3, Trial 28: num_city=10, bound=(-100, 100), start_position=17525244
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_29\QuasiRandom.txt
# Run 3, Trial 29: num_city=10, bound=(-100, 100), start_position=19901671
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_30\QuasiRandom.txt
# Run 3, Trial 30: num_city=10, bound=(-100, 100), start_position=64312995
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_11\QuasiRandom.txt
# Run 4, Trial 11: num_city=10, bound=(-100, 100), start_position=48828916
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_12\QuasiRandom.txt
# Run 4, Trial 12: num_city=10, bound=(-100, 100), start_position=50726131
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_13\QuasiRandom.txt
# Run 4, Trial 13: num_city=10, bound=(-100, 100), start_position=26280466
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_14\QuasiRandom.txt
# Run 4, Trial 14: num_city=10, bound=(-100, 100), start_position=81367433
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_15\QuasiRandom.txt
# Run 4, Trial 15: num_city=10, bound=(-100, 100), start_position=54872652
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_16\QuasiRandom.txt
# Run 4, Trial 16: num_city=10, bound=(-100, 100), start_position=5193599
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_17\QuasiRandom.txt
# Run 4, Trial 17: num_city=10, bound=(-100, 100), start_position=9378761
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_18\QuasiRandom.txt
# Run 4, Trial 18: num_city=10, bound=(-100, 100), start_position=20010294
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_19\QuasiRandom.txt
# Run 4, Trial 19: num_city=10, bound=(-100, 100), start_position=25058001
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_20\QuasiRandom.txt
# Run 4, Trial 20: num_city=10, bound=(-100, 100), start_position=45892938
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_21\QuasiRandom.txt
# Run 4, Trial 21: num_city=10, bound=(-100, 100), start_position=21011740
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_22\QuasiRandom.txt
# Run 4, Trial 22: num_city=10, bound=(-100, 100), start_position=7712120
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_23\QuasiRandom.txt
# Run 4, Trial 23: num_city=10, bound=(-100, 100), start_position=8724471
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_24\QuasiRandom.txt
# Run 4, Trial 24: num_city=10, bound=(-100, 100), start_position=53781623
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_25\QuasiRandom.txt
# Run 4, Trial 25: num_city=10, bound=(-100, 100), start_position=48774093
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_26\QuasiRandom.txt
# Run 4, Trial 26: num_city=10, bound=(-100, 100), start_position=41586108
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_27\QuasiRandom.txt
# Run 4, Trial 27: num_city=10, bound=(-100, 100), start_position=52794938
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_28\QuasiRandom.txt
# Run 4, Trial 28: num_city=10, bound=(-100, 100), start_position=35337191
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_29\QuasiRandom.txt
# Run 4, Trial 29: num_city=10, bound=(-100, 100), start_position=79680205
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_30\QuasiRandom.txt
# Run 4, Trial 30: num_city=10, bound=(-100, 100), start_position=70934966
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_11\QuasiRandom.txt
# Run 5, Trial 11: num_city=10, bound=(-100, 100), start_position=70861241
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_12\QuasiRandom.txt
# Run 5, Trial 12: num_city=10, bound=(-100, 100), start_position=61820825
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_13\QuasiRandom.txt
# Run 5, Trial 13: num_city=10, bound=(-100, 100), start_position=76072101
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_14\QuasiRandom.txt
# Run 5, Trial 14: num_city=10, bound=(-100, 100), start_position=15321893
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_15\QuasiRandom.txt
# Run 5, Trial 15: num_city=10, bound=(-100, 100), start_position=70635534
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_16\QuasiRandom.txt
# Run 5, Trial 16: num_city=10, bound=(-100, 100), start_position=49828635
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_17\QuasiRandom.txt
# Run 5, Trial 17: num_city=10, bound=(-100, 100), start_position=66931452
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_18\QuasiRandom.txt
# Run 5, Trial 18: num_city=10, bound=(-100, 100), start_position=51492733
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_19\QuasiRandom.txt
# Run 5, Trial 19: num_city=10, bound=(-100, 100), start_position=2471102
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_20\QuasiRandom.txt
# Run 5, Trial 20: num_city=10, bound=(-100, 100), start_position=51260401
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_21\QuasiRandom.txt
# Run 5, Trial 21: num_city=10, bound=(-100, 100), start_position=68460952
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_22\QuasiRandom.txt
# Run 5, Trial 22: num_city=10, bound=(-100, 100), start_position=23704719
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_23\QuasiRandom.txt
# Run 5, Trial 23: num_city=10, bound=(-100, 100), start_position=79472472
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_24\QuasiRandom.txt
# Run 5, Trial 24: num_city=10, bound=(-100, 100), start_position=53498990
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_25\QuasiRandom.txt
# Run 5, Trial 25: num_city=10, bound=(-100, 100), start_position=49093863
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_26\QuasiRandom.txt
# Run 5, Trial 26: num_city=10, bound=(-100, 100), start_position=52798658
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_27\QuasiRandom.txt
# Run 5, Trial 27: num_city=10, bound=(-100, 100), start_position=73568836
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_28\QuasiRandom.txt
# Run 5, Trial 28: num_city=10, bound=(-100, 100), start_position=63589049
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_29\QuasiRandom.txt
# Run 5, Trial 29: num_city=10, bound=(-100, 100), start_position=30358138
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_30\QuasiRandom.txt
# Run 5, Trial 30: num_city=10, bound=(-100, 100), start_position=68612212
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_11\QuasiRandom.txt
# Run 6, Trial 11: num_city=10, bound=(-100, 100), start_position=3986911
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_12\QuasiRandom.txt
# Run 6, Trial 12: num_city=10, bound=(-100, 100), start_position=39506968
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_13\QuasiRandom.txt
# Run 6, Trial 13: num_city=10, bound=(-100, 100), start_position=43202202
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_14\QuasiRandom.txt
# Run 6, Trial 14: num_city=10, bound=(-100, 100), start_position=71033165
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_15\QuasiRandom.txt
# Run 6, Trial 15: num_city=10, bound=(-100, 100), start_position=30546018
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_16\QuasiRandom.txt
# Run 6, Trial 16: num_city=10, bound=(-100, 100), start_position=75048170
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_17\QuasiRandom.txt
# Run 6, Trial 17: num_city=10, bound=(-100, 100), start_position=37777011
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_18\QuasiRandom.txt
# Run 6, Trial 18: num_city=10, bound=(-100, 100), start_position=27049091
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_19\QuasiRandom.txt
# Run 6, Trial 19: num_city=10, bound=(-100, 100), start_position=62729533
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_20\QuasiRandom.txt
# Run 6, Trial 20: num_city=10, bound=(-100, 100), start_position=70800958
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_21\QuasiRandom.txt
# Run 6, Trial 21: num_city=10, bound=(-100, 100), start_position=39201921
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_22\QuasiRandom.txt
# Run 6, Trial 22: num_city=10, bound=(-100, 100), start_position=30255471
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_23\QuasiRandom.txt
# Run 6, Trial 23: num_city=10, bound=(-100, 100), start_position=70046853
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_24\QuasiRandom.txt
# Run 6, Trial 24: num_city=10, bound=(-100, 100), start_position=21384803
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_25\QuasiRandom.txt
# Run 6, Trial 25: num_city=10, bound=(-100, 100), start_position=30030265
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_26\QuasiRandom.txt
# Run 6, Trial 26: num_city=10, bound=(-100, 100), start_position=43185819
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_27\QuasiRandom.txt
# Run 6, Trial 27: num_city=10, bound=(-100, 100), start_position=22856570
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_28\QuasiRandom.txt
# Run 6, Trial 28: num_city=10, bound=(-100, 100), start_position=40049212
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_29\QuasiRandom.txt
# Run 6, Trial 29: num_city=10, bound=(-100, 100), start_position=47616035
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_30\QuasiRandom.txt
# Run 6, Trial 30: num_city=10, bound=(-100, 100), start_position=6601692
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_11\QuasiRandom.txt
# Run 7, Trial 11: num_city=10, bound=(-100, 100), start_position=47941669
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_12\QuasiRandom.txt
# Run 7, Trial 12: num_city=10, bound=(-100, 100), start_position=38318713
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_13\QuasiRandom.txt
# Run 7, Trial 13: num_city=10, bound=(-100, 100), start_position=63895548
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_14\QuasiRandom.txt
# Run 7, Trial 14: num_city=10, bound=(-100, 100), start_position=40945209
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_15\QuasiRandom.txt
# Run 7, Trial 15: num_city=10, bound=(-100, 100), start_position=41956377
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_16\QuasiRandom.txt
# Run 7, Trial 16: num_city=10, bound=(-100, 100), start_position=60877361
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_17\QuasiRandom.txt
# Run 7, Trial 17: num_city=10, bound=(-100, 100), start_position=9883352
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_18\QuasiRandom.txt
# Run 7, Trial 18: num_city=10, bound=(-100, 100), start_position=41332412
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_19\QuasiRandom.txt
# Run 7, Trial 19: num_city=10, bound=(-100, 100), start_position=81943574
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_20\QuasiRandom.txt
# Run 7, Trial 20: num_city=10, bound=(-100, 100), start_position=27260037
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_21\QuasiRandom.txt
# Run 7, Trial 21: num_city=10, bound=(-100, 100), start_position=20319406
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_22\QuasiRandom.txt
# Run 7, Trial 22: num_city=10, bound=(-100, 100), start_position=50358174
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_23\QuasiRandom.txt
# Run 7, Trial 23: num_city=10, bound=(-100, 100), start_position=46317867
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_24\QuasiRandom.txt
# Run 7, Trial 24: num_city=10, bound=(-100, 100), start_position=35622826
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_25\QuasiRandom.txt
# Run 7, Trial 25: num_city=10, bound=(-100, 100), start_position=69763911
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_26\QuasiRandom.txt
# Run 7, Trial 26: num_city=10, bound=(-100, 100), start_position=26546916
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_27\QuasiRandom.txt
# Run 7, Trial 27: num_city=10, bound=(-100, 100), start_position=19977636
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_28\QuasiRandom.txt
# Run 7, Trial 28: num_city=10, bound=(-100, 100), start_position=55737535
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_29\QuasiRandom.txt
# Run 7, Trial 29: num_city=10, bound=(-100, 100), start_position=33008501
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_30\QuasiRandom.txt
# Run 7, Trial 30: num_city=10, bound=(-100, 100), start_position=6912592
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_11\QuasiRandom.txt
# Run 8, Trial 11: num_city=10, bound=(-100, 100), start_position=45645465
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_12\QuasiRandom.txt
# Run 8, Trial 12: num_city=10, bound=(-100, 100), start_position=57816280
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_13\QuasiRandom.txt
# Run 8, Trial 13: num_city=10, bound=(-100, 100), start_position=74873409
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_14\QuasiRandom.txt
# Run 8, Trial 14: num_city=10, bound=(-100, 100), start_position=49688379
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_15\QuasiRandom.txt
# Run 8, Trial 15: num_city=10, bound=(-100, 100), start_position=14291682
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_16\QuasiRandom.txt
# Run 8, Trial 16: num_city=10, bound=(-100, 100), start_position=6488533
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_17\QuasiRandom.txt
# Run 8, Trial 17: num_city=10, bound=(-100, 100), start_position=58530438
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_18\QuasiRandom.txt
# Run 8, Trial 18: num_city=10, bound=(-100, 100), start_position=40116328
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_19\QuasiRandom.txt
# Run 8, Trial 19: num_city=10, bound=(-100, 100), start_position=40501552
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_20\QuasiRandom.txt
# Run 8, Trial 20: num_city=10, bound=(-100, 100), start_position=76282266
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_21\QuasiRandom.txt
# Run 8, Trial 21: num_city=10, bound=(-100, 100), start_position=82039054
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_22\QuasiRandom.txt
# Run 8, Trial 22: num_city=10, bound=(-100, 100), start_position=21134950
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_23\QuasiRandom.txt
# Run 8, Trial 23: num_city=10, bound=(-100, 100), start_position=69333992
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_24\QuasiRandom.txt
# Run 8, Trial 24: num_city=10, bound=(-100, 100), start_position=66631661
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_25\QuasiRandom.txt
# Run 8, Trial 25: num_city=10, bound=(-100, 100), start_position=19902152
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_26\QuasiRandom.txt
# Run 8, Trial 26: num_city=10, bound=(-100, 100), start_position=24689701
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_27\QuasiRandom.txt
# Run 8, Trial 27: num_city=10, bound=(-100, 100), start_position=56142760
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_28\QuasiRandom.txt
# Run 8, Trial 28: num_city=10, bound=(-100, 100), start_position=10233073
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_29\QuasiRandom.txt
# Run 8, Trial 29: num_city=10, bound=(-100, 100), start_position=6492259
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_30\QuasiRandom.txt
# Run 8, Trial 30: num_city=10, bound=(-100, 100), start_position=49282843
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_11\QuasiRandom.txt
# Run 9, Trial 11: num_city=10, bound=(-100, 100), start_position=81758725
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_12\QuasiRandom.txt
# Run 9, Trial 12: num_city=10, bound=(-100, 100), start_position=73227700
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_13\QuasiRandom.txt
# Run 9, Trial 13: num_city=10, bound=(-100, 100), start_position=20680021
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_14\QuasiRandom.txt
# Run 9, Trial 14: num_city=10, bound=(-100, 100), start_position=7679420
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_15\QuasiRandom.txt
# Run 9, Trial 15: num_city=10, bound=(-100, 100), start_position=29785276
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_16\QuasiRandom.txt
# Run 9, Trial 16: num_city=10, bound=(-100, 100), start_position=1171100
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_17\QuasiRandom.txt
# Run 9, Trial 17: num_city=10, bound=(-100, 100), start_position=2661184
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_18\QuasiRandom.txt
# Run 9, Trial 18: num_city=10, bound=(-100, 100), start_position=40143889
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_19\QuasiRandom.txt
# Run 9, Trial 19: num_city=10, bound=(-100, 100), start_position=67653680
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_20\QuasiRandom.txt
# Run 9, Trial 20: num_city=10, bound=(-100, 100), start_position=67801801
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_21\QuasiRandom.txt
# Run 9, Trial 21: num_city=10, bound=(-100, 100), start_position=69498578
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_22\QuasiRandom.txt
# Run 9, Trial 22: num_city=10, bound=(-100, 100), start_position=78092193
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_23\QuasiRandom.txt
# Run 9, Trial 23: num_city=10, bound=(-100, 100), start_position=13449356
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_24\QuasiRandom.txt
# Run 9, Trial 24: num_city=10, bound=(-100, 100), start_position=37572942
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_25\QuasiRandom.txt
# Run 9, Trial 25: num_city=10, bound=(-100, 100), start_position=2645470
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_26\QuasiRandom.txt
# Run 9, Trial 26: num_city=10, bound=(-100, 100), start_position=4902142
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_27\QuasiRandom.txt
# Run 9, Trial 27: num_city=10, bound=(-100, 100), start_position=81463305
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_28\QuasiRandom.txt
# Run 9, Trial 28: num_city=10, bound=(-100, 100), start_position=34700869
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_29\QuasiRandom.txt
# Run 9, Trial 29: num_city=10, bound=(-100, 100), start_position=69562847
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_30\QuasiRandom.txt
# Run 9, Trial 30: num_city=10, bound=(-100, 100), start_position=40010045
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_11\QuasiRandom.txt
# Run 10, Trial 11: num_city=10, bound=(-100, 100), start_position=45665250
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_12\QuasiRandom.txt
# Run 10, Trial 12: num_city=10, bound=(-100, 100), start_position=59468221
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_13\QuasiRandom.txt
# Run 10, Trial 13: num_city=10, bound=(-100, 100), start_position=15618241
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_14\QuasiRandom.txt
# Run 10, Trial 14: num_city=10, bound=(-100, 100), start_position=75384987
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_15\QuasiRandom.txt
# Run 10, Trial 15: num_city=10, bound=(-100, 100), start_position=33081634
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_16\QuasiRandom.txt
# Run 10, Trial 16: num_city=10, bound=(-100, 100), start_position=43884745
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_17\QuasiRandom.txt
# Run 10, Trial 17: num_city=10, bound=(-100, 100), start_position=66585364
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_18\QuasiRandom.txt
# Run 10, Trial 18: num_city=10, bound=(-100, 100), start_position=53096780
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_19\QuasiRandom.txt
# Run 10, Trial 19: num_city=10, bound=(-100, 100), start_position=42816769
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_20\QuasiRandom.txt
# Run 10, Trial 20: num_city=10, bound=(-100, 100), start_position=46844516
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_21\QuasiRandom.txt
# Run 10, Trial 21: num_city=10, bound=(-100, 100), start_position=65897728
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_22\QuasiRandom.txt
# Run 10, Trial 22: num_city=10, bound=(-100, 100), start_position=15774685
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_23\QuasiRandom.txt
# Run 10, Trial 23: num_city=10, bound=(-100, 100), start_position=43192758
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_24\QuasiRandom.txt
# Run 10, Trial 24: num_city=10, bound=(-100, 100), start_position=16277620
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_25\QuasiRandom.txt
# Run 10, Trial 25: num_city=10, bound=(-100, 100), start_position=66119017
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_26\QuasiRandom.txt
# Run 10, Trial 26: num_city=10, bound=(-100, 100), start_position=25735041
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_27\QuasiRandom.txt
# Run 10, Trial 27: num_city=10, bound=(-100, 100), start_position=9710686
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_28\QuasiRandom.txt
# Run 10, Trial 28: num_city=10, bound=(-100, 100), start_position=60019314
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_29\QuasiRandom.txt
# Run 10, Trial 29: num_city=10, bound=(-100, 100), start_position=5443681
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_30\QuasiRandom.txt
# Run 10, Trial 30: num_city=10, bound=(-100, 100), start_position=31158996

# %%
# Run the process 10 times, each with a different num_city value and saving in a new location
for run_index in range(1, 11):  # 10 separate runs
    num_city, bound = input_sets[run_index - 1]  # Get num_city and bound from the input set
    
    # Define the **run-specific** directory (F12021, F22021, ..., F102021)
    base_output_dir = os.path.join("starting_solution", "CEC2021", f"F{run_index}2021")
    os.makedirs(base_output_dir, exist_ok=True)  # Ensure the base directory exists
    
    # Run 10 trials per run
    for trial_index in range(11, num_trials + 1):  
        # Define the subdirectory for each trial
        trial_dir = os.path.join(base_output_dir, f"trial_{trial_index}")
        os.makedirs(trial_dir, exist_ok=True)  # Ensure the trial directory exists
        
        # Define the file path
        output_file_path = os.path.join(trial_dir, "Mt19937.txt")

        # Process the normalization data and save to the file
        start = process_normalization_f12021_data(
            data=Mt19937, 
            num_city=num_city, 
            pop_size=100, 
            file_path=output_file_path, 
            bound=bound
        )

        # Print the expected output format
        print(f"Run {run_index}, Trial {trial_index}: num_city={num_city}, bound={bound}, start_position={start}")
# Out:
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_11\Mt19937.txt
# Run 1, Trial 11: num_city=10, bound=(-100, 100), start_position=2216578
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_12\Mt19937.txt
# Run 1, Trial 12: num_city=10, bound=(-100, 100), start_position=53880028
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_13\Mt19937.txt
# Run 1, Trial 13: num_city=10, bound=(-100, 100), start_position=59098772
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_14\Mt19937.txt
# Run 1, Trial 14: num_city=10, bound=(-100, 100), start_position=38659599
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_15\Mt19937.txt
# Run 1, Trial 15: num_city=10, bound=(-100, 100), start_position=35129622
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_16\Mt19937.txt
# Run 1, Trial 16: num_city=10, bound=(-100, 100), start_position=34788421
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_17\Mt19937.txt
# Run 1, Trial 17: num_city=10, bound=(-100, 100), start_position=17079446
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_18\Mt19937.txt
# Run 1, Trial 18: num_city=10, bound=(-100, 100), start_position=64072606
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_19\Mt19937.txt
# Run 1, Trial 19: num_city=10, bound=(-100, 100), start_position=16167548
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_20\Mt19937.txt
# Run 1, Trial 20: num_city=10, bound=(-100, 100), start_position=32854163
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_21\Mt19937.txt
# Run 1, Trial 21: num_city=10, bound=(-100, 100), start_position=74269931
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_22\Mt19937.txt
# Run 1, Trial 22: num_city=10, bound=(-100, 100), start_position=24146129
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_23\Mt19937.txt
# Run 1, Trial 23: num_city=10, bound=(-100, 100), start_position=74049969
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_24\Mt19937.txt
# Run 1, Trial 24: num_city=10, bound=(-100, 100), start_position=24974656
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_25\Mt19937.txt
# Run 1, Trial 25: num_city=10, bound=(-100, 100), start_position=81890462
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_26\Mt19937.txt
# Run 1, Trial 26: num_city=10, bound=(-100, 100), start_position=46403865
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_27\Mt19937.txt
# Run 1, Trial 27: num_city=10, bound=(-100, 100), start_position=41219444
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_28\Mt19937.txt
# Run 1, Trial 28: num_city=10, bound=(-100, 100), start_position=6227263
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_29\Mt19937.txt
# Run 1, Trial 29: num_city=10, bound=(-100, 100), start_position=61015655
# Normalized sets saved to starting_solution\CEC2021\F12021\trial_30\Mt19937.txt
# Run 1, Trial 30: num_city=10, bound=(-100, 100), start_position=4972149
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_11\Mt19937.txt
# Run 2, Trial 11: num_city=10, bound=(-100, 100), start_position=3540193
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_12\Mt19937.txt
# Run 2, Trial 12: num_city=10, bound=(-100, 100), start_position=66511741
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_13\Mt19937.txt
# Run 2, Trial 13: num_city=10, bound=(-100, 100), start_position=72211470
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_14\Mt19937.txt
# Run 2, Trial 14: num_city=10, bound=(-100, 100), start_position=4579967
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_15\Mt19937.txt
# Run 2, Trial 15: num_city=10, bound=(-100, 100), start_position=34109669
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_16\Mt19937.txt
# Run 2, Trial 16: num_city=10, bound=(-100, 100), start_position=13224118
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_17\Mt19937.txt
# Run 2, Trial 17: num_city=10, bound=(-100, 100), start_position=37644778
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_18\Mt19937.txt
# Run 2, Trial 18: num_city=10, bound=(-100, 100), start_position=63374060
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_19\Mt19937.txt
# Run 2, Trial 19: num_city=10, bound=(-100, 100), start_position=29812571
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_20\Mt19937.txt
# Run 2, Trial 20: num_city=10, bound=(-100, 100), start_position=22168199
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_21\Mt19937.txt
# Run 2, Trial 21: num_city=10, bound=(-100, 100), start_position=10762804
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_22\Mt19937.txt
# Run 2, Trial 22: num_city=10, bound=(-100, 100), start_position=80583557
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_23\Mt19937.txt
# Run 2, Trial 23: num_city=10, bound=(-100, 100), start_position=65281800
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_24\Mt19937.txt
# Run 2, Trial 24: num_city=10, bound=(-100, 100), start_position=59362891
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_25\Mt19937.txt
# Run 2, Trial 25: num_city=10, bound=(-100, 100), start_position=77868649
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_26\Mt19937.txt
# Run 2, Trial 26: num_city=10, bound=(-100, 100), start_position=70659889
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_27\Mt19937.txt
# Run 2, Trial 27: num_city=10, bound=(-100, 100), start_position=33348396
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_28\Mt19937.txt
# Run 2, Trial 28: num_city=10, bound=(-100, 100), start_position=53880903
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_29\Mt19937.txt
# Run 2, Trial 29: num_city=10, bound=(-100, 100), start_position=10257994
# Normalized sets saved to starting_solution\CEC2021\F22021\trial_30\Mt19937.txt
# Run 2, Trial 30: num_city=10, bound=(-100, 100), start_position=38317101
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_11\Mt19937.txt
# Run 3, Trial 11: num_city=10, bound=(-100, 100), start_position=12582311
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_12\Mt19937.txt
# Run 3, Trial 12: num_city=10, bound=(-100, 100), start_position=41150969
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_13\Mt19937.txt
# Run 3, Trial 13: num_city=10, bound=(-100, 100), start_position=826700
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_14\Mt19937.txt
# Run 3, Trial 14: num_city=10, bound=(-100, 100), start_position=34733430
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_15\Mt19937.txt
# Run 3, Trial 15: num_city=10, bound=(-100, 100), start_position=43447136
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_16\Mt19937.txt
# Run 3, Trial 16: num_city=10, bound=(-100, 100), start_position=44342604
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_17\Mt19937.txt
# Run 3, Trial 17: num_city=10, bound=(-100, 100), start_position=7156131
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_18\Mt19937.txt
# Run 3, Trial 18: num_city=10, bound=(-100, 100), start_position=57544516
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_19\Mt19937.txt
# Run 3, Trial 19: num_city=10, bound=(-100, 100), start_position=30574363
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_20\Mt19937.txt
# Run 3, Trial 20: num_city=10, bound=(-100, 100), start_position=79176445
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_21\Mt19937.txt
# Run 3, Trial 21: num_city=10, bound=(-100, 100), start_position=51171074
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_22\Mt19937.txt
# Run 3, Trial 22: num_city=10, bound=(-100, 100), start_position=50818814
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_23\Mt19937.txt
# Run 3, Trial 23: num_city=10, bound=(-100, 100), start_position=45040777
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_24\Mt19937.txt
# Run 3, Trial 24: num_city=10, bound=(-100, 100), start_position=51140347
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_25\Mt19937.txt
# Run 3, Trial 25: num_city=10, bound=(-100, 100), start_position=73514297
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_26\Mt19937.txt
# Run 3, Trial 26: num_city=10, bound=(-100, 100), start_position=49518309
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_27\Mt19937.txt
# Run 3, Trial 27: num_city=10, bound=(-100, 100), start_position=68076341
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_28\Mt19937.txt
# Run 3, Trial 28: num_city=10, bound=(-100, 100), start_position=73409248
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_29\Mt19937.txt
# Run 3, Trial 29: num_city=10, bound=(-100, 100), start_position=17426099
# Normalized sets saved to starting_solution\CEC2021\F32021\trial_30\Mt19937.txt
# Run 3, Trial 30: num_city=10, bound=(-100, 100), start_position=25977890
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_11\Mt19937.txt
# Run 4, Trial 11: num_city=10, bound=(-100, 100), start_position=34813119
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_12\Mt19937.txt
# Run 4, Trial 12: num_city=10, bound=(-100, 100), start_position=14875605
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_13\Mt19937.txt
# Run 4, Trial 13: num_city=10, bound=(-100, 100), start_position=59732004
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_14\Mt19937.txt
# Run 4, Trial 14: num_city=10, bound=(-100, 100), start_position=13446819
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_15\Mt19937.txt
# Run 4, Trial 15: num_city=10, bound=(-100, 100), start_position=40568795
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_16\Mt19937.txt
# Run 4, Trial 16: num_city=10, bound=(-100, 100), start_position=3492901
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_17\Mt19937.txt
# Run 4, Trial 17: num_city=10, bound=(-100, 100), start_position=56046336
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_18\Mt19937.txt
# Run 4, Trial 18: num_city=10, bound=(-100, 100), start_position=76192626
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_19\Mt19937.txt
# Run 4, Trial 19: num_city=10, bound=(-100, 100), start_position=55236379
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_20\Mt19937.txt
# Run 4, Trial 20: num_city=10, bound=(-100, 100), start_position=80503986
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_21\Mt19937.txt
# Run 4, Trial 21: num_city=10, bound=(-100, 100), start_position=32634305
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_22\Mt19937.txt
# Run 4, Trial 22: num_city=10, bound=(-100, 100), start_position=71430297
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_23\Mt19937.txt
# Run 4, Trial 23: num_city=10, bound=(-100, 100), start_position=20576334
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_24\Mt19937.txt
# Run 4, Trial 24: num_city=10, bound=(-100, 100), start_position=8079983
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_25\Mt19937.txt
# Run 4, Trial 25: num_city=10, bound=(-100, 100), start_position=17496252
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_26\Mt19937.txt
# Run 4, Trial 26: num_city=10, bound=(-100, 100), start_position=50421333
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_27\Mt19937.txt
# Run 4, Trial 27: num_city=10, bound=(-100, 100), start_position=16922866
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_28\Mt19937.txt
# Run 4, Trial 28: num_city=10, bound=(-100, 100), start_position=48139082
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_29\Mt19937.txt
# Run 4, Trial 29: num_city=10, bound=(-100, 100), start_position=15180224
# Normalized sets saved to starting_solution\CEC2021\F42021\trial_30\Mt19937.txt
# Run 4, Trial 30: num_city=10, bound=(-100, 100), start_position=56253238
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_11\Mt19937.txt
# Run 5, Trial 11: num_city=10, bound=(-100, 100), start_position=14851928
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_12\Mt19937.txt
# Run 5, Trial 12: num_city=10, bound=(-100, 100), start_position=80993975
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_13\Mt19937.txt
# Run 5, Trial 13: num_city=10, bound=(-100, 100), start_position=3838842
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_14\Mt19937.txt
# Run 5, Trial 14: num_city=10, bound=(-100, 100), start_position=30588371
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_15\Mt19937.txt
# Run 5, Trial 15: num_city=10, bound=(-100, 100), start_position=53056735
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_16\Mt19937.txt
# Run 5, Trial 16: num_city=10, bound=(-100, 100), start_position=48021731
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_17\Mt19937.txt
# Run 5, Trial 17: num_city=10, bound=(-100, 100), start_position=70083687
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_18\Mt19937.txt
# Run 5, Trial 18: num_city=10, bound=(-100, 100), start_position=17844025
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_19\Mt19937.txt
# Run 5, Trial 19: num_city=10, bound=(-100, 100), start_position=8789736
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_20\Mt19937.txt
# Run 5, Trial 20: num_city=10, bound=(-100, 100), start_position=72667198
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_21\Mt19937.txt
# Run 5, Trial 21: num_city=10, bound=(-100, 100), start_position=27788909
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_22\Mt19937.txt
# Run 5, Trial 22: num_city=10, bound=(-100, 100), start_position=88429
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_23\Mt19937.txt
# Run 5, Trial 23: num_city=10, bound=(-100, 100), start_position=81095945
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_24\Mt19937.txt
# Run 5, Trial 24: num_city=10, bound=(-100, 100), start_position=31966556
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_25\Mt19937.txt
# Run 5, Trial 25: num_city=10, bound=(-100, 100), start_position=73870127
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_26\Mt19937.txt
# Run 5, Trial 26: num_city=10, bound=(-100, 100), start_position=39783993
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_27\Mt19937.txt
# Run 5, Trial 27: num_city=10, bound=(-100, 100), start_position=68739000
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_28\Mt19937.txt
# Run 5, Trial 28: num_city=10, bound=(-100, 100), start_position=79571210
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_29\Mt19937.txt
# Run 5, Trial 29: num_city=10, bound=(-100, 100), start_position=57179645
# Normalized sets saved to starting_solution\CEC2021\F52021\trial_30\Mt19937.txt
# Run 5, Trial 30: num_city=10, bound=(-100, 100), start_position=31334669
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_11\Mt19937.txt
# Run 6, Trial 11: num_city=10, bound=(-100, 100), start_position=30364968
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_12\Mt19937.txt
# Run 6, Trial 12: num_city=10, bound=(-100, 100), start_position=22699043
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_13\Mt19937.txt
# Run 6, Trial 13: num_city=10, bound=(-100, 100), start_position=52848203
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_14\Mt19937.txt
# Run 6, Trial 14: num_city=10, bound=(-100, 100), start_position=1307028
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_15\Mt19937.txt
# Run 6, Trial 15: num_city=10, bound=(-100, 100), start_position=71355969
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_16\Mt19937.txt
# Run 6, Trial 16: num_city=10, bound=(-100, 100), start_position=45427136
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_17\Mt19937.txt
# Run 6, Trial 17: num_city=10, bound=(-100, 100), start_position=12718057
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_18\Mt19937.txt
# Run 6, Trial 18: num_city=10, bound=(-100, 100), start_position=17130698
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_19\Mt19937.txt
# Run 6, Trial 19: num_city=10, bound=(-100, 100), start_position=54884784
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_20\Mt19937.txt
# Run 6, Trial 20: num_city=10, bound=(-100, 100), start_position=42471539
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_21\Mt19937.txt
# Run 6, Trial 21: num_city=10, bound=(-100, 100), start_position=69474639
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_22\Mt19937.txt
# Run 6, Trial 22: num_city=10, bound=(-100, 100), start_position=57744474
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_23\Mt19937.txt
# Run 6, Trial 23: num_city=10, bound=(-100, 100), start_position=53435297
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_24\Mt19937.txt
# Run 6, Trial 24: num_city=10, bound=(-100, 100), start_position=851479
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_25\Mt19937.txt
# Run 6, Trial 25: num_city=10, bound=(-100, 100), start_position=877244
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_26\Mt19937.txt
# Run 6, Trial 26: num_city=10, bound=(-100, 100), start_position=59835093
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_27\Mt19937.txt
# Run 6, Trial 27: num_city=10, bound=(-100, 100), start_position=56942654
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_28\Mt19937.txt
# Run 6, Trial 28: num_city=10, bound=(-100, 100), start_position=49763451
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_29\Mt19937.txt
# Run 6, Trial 29: num_city=10, bound=(-100, 100), start_position=66216
# Normalized sets saved to starting_solution\CEC2021\F62021\trial_30\Mt19937.txt
# Run 6, Trial 30: num_city=10, bound=(-100, 100), start_position=62866383
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_11\Mt19937.txt
# Run 7, Trial 11: num_city=10, bound=(-100, 100), start_position=70793043
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_12\Mt19937.txt
# Run 7, Trial 12: num_city=10, bound=(-100, 100), start_position=49608819
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_13\Mt19937.txt
# Run 7, Trial 13: num_city=10, bound=(-100, 100), start_position=67637365
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_14\Mt19937.txt
# Run 7, Trial 14: num_city=10, bound=(-100, 100), start_position=31768600
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_15\Mt19937.txt
# Run 7, Trial 15: num_city=10, bound=(-100, 100), start_position=23887161
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_16\Mt19937.txt
# Run 7, Trial 16: num_city=10, bound=(-100, 100), start_position=81416474
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_17\Mt19937.txt
# Run 7, Trial 17: num_city=10, bound=(-100, 100), start_position=21300712
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_18\Mt19937.txt
# Run 7, Trial 18: num_city=10, bound=(-100, 100), start_position=75402795
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_19\Mt19937.txt
# Run 7, Trial 19: num_city=10, bound=(-100, 100), start_position=57059417
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_20\Mt19937.txt
# Run 7, Trial 20: num_city=10, bound=(-100, 100), start_position=65235522
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_21\Mt19937.txt
# Run 7, Trial 21: num_city=10, bound=(-100, 100), start_position=28471335
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_22\Mt19937.txt
# Run 7, Trial 22: num_city=10, bound=(-100, 100), start_position=12257889
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_23\Mt19937.txt
# Run 7, Trial 23: num_city=10, bound=(-100, 100), start_position=73695979
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_24\Mt19937.txt
# Run 7, Trial 24: num_city=10, bound=(-100, 100), start_position=8668485
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_25\Mt19937.txt
# Run 7, Trial 25: num_city=10, bound=(-100, 100), start_position=33654082
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_26\Mt19937.txt
# Run 7, Trial 26: num_city=10, bound=(-100, 100), start_position=69647786
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_27\Mt19937.txt
# Run 7, Trial 27: num_city=10, bound=(-100, 100), start_position=37246950
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_28\Mt19937.txt
# Run 7, Trial 28: num_city=10, bound=(-100, 100), start_position=10565431
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_29\Mt19937.txt
# Run 7, Trial 29: num_city=10, bound=(-100, 100), start_position=69727994
# Normalized sets saved to starting_solution\CEC2021\F72021\trial_30\Mt19937.txt
# Run 7, Trial 30: num_city=10, bound=(-100, 100), start_position=14926785
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_11\Mt19937.txt
# Run 8, Trial 11: num_city=10, bound=(-100, 100), start_position=69838746
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_12\Mt19937.txt
# Run 8, Trial 12: num_city=10, bound=(-100, 100), start_position=66244475
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_13\Mt19937.txt
# Run 8, Trial 13: num_city=10, bound=(-100, 100), start_position=62964837
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_14\Mt19937.txt
# Run 8, Trial 14: num_city=10, bound=(-100, 100), start_position=33468396
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_15\Mt19937.txt
# Run 8, Trial 15: num_city=10, bound=(-100, 100), start_position=23999466
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_16\Mt19937.txt
# Run 8, Trial 16: num_city=10, bound=(-100, 100), start_position=72619761
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_17\Mt19937.txt
# Run 8, Trial 17: num_city=10, bound=(-100, 100), start_position=3474031
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_18\Mt19937.txt
# Run 8, Trial 18: num_city=10, bound=(-100, 100), start_position=80574623
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_19\Mt19937.txt
# Run 8, Trial 19: num_city=10, bound=(-100, 100), start_position=18183203
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_20\Mt19937.txt
# Run 8, Trial 20: num_city=10, bound=(-100, 100), start_position=66487250
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_21\Mt19937.txt
# Run 8, Trial 21: num_city=10, bound=(-100, 100), start_position=59595484
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_22\Mt19937.txt
# Run 8, Trial 22: num_city=10, bound=(-100, 100), start_position=32040597
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_23\Mt19937.txt
# Run 8, Trial 23: num_city=10, bound=(-100, 100), start_position=29067549
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_24\Mt19937.txt
# Run 8, Trial 24: num_city=10, bound=(-100, 100), start_position=47705777
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_25\Mt19937.txt
# Run 8, Trial 25: num_city=10, bound=(-100, 100), start_position=17455739
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_26\Mt19937.txt
# Run 8, Trial 26: num_city=10, bound=(-100, 100), start_position=66092688
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_27\Mt19937.txt
# Run 8, Trial 27: num_city=10, bound=(-100, 100), start_position=24752263
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_28\Mt19937.txt
# Run 8, Trial 28: num_city=10, bound=(-100, 100), start_position=35313756
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_29\Mt19937.txt
# Run 8, Trial 29: num_city=10, bound=(-100, 100), start_position=53945709
# Normalized sets saved to starting_solution\CEC2021\F82021\trial_30\Mt19937.txt
# Run 8, Trial 30: num_city=10, bound=(-100, 100), start_position=50697639
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_11\Mt19937.txt
# Run 9, Trial 11: num_city=10, bound=(-100, 100), start_position=35765781
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_12\Mt19937.txt
# Run 9, Trial 12: num_city=10, bound=(-100, 100), start_position=55480115
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_13\Mt19937.txt
# Run 9, Trial 13: num_city=10, bound=(-100, 100), start_position=4971872
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_14\Mt19937.txt
# Run 9, Trial 14: num_city=10, bound=(-100, 100), start_position=33502576
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_15\Mt19937.txt
# Run 9, Trial 15: num_city=10, bound=(-100, 100), start_position=7902133
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_16\Mt19937.txt
# Run 9, Trial 16: num_city=10, bound=(-100, 100), start_position=4288062
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_17\Mt19937.txt
# Run 9, Trial 17: num_city=10, bound=(-100, 100), start_position=16956199
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_18\Mt19937.txt
# Run 9, Trial 18: num_city=10, bound=(-100, 100), start_position=57364875
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_19\Mt19937.txt
# Run 9, Trial 19: num_city=10, bound=(-100, 100), start_position=22497856
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_20\Mt19937.txt
# Run 9, Trial 20: num_city=10, bound=(-100, 100), start_position=48932939
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_21\Mt19937.txt
# Run 9, Trial 21: num_city=10, bound=(-100, 100), start_position=23012159
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_22\Mt19937.txt
# Run 9, Trial 22: num_city=10, bound=(-100, 100), start_position=61661783
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_23\Mt19937.txt
# Run 9, Trial 23: num_city=10, bound=(-100, 100), start_position=62091613
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_24\Mt19937.txt
# Run 9, Trial 24: num_city=10, bound=(-100, 100), start_position=52684794
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_25\Mt19937.txt
# Run 9, Trial 25: num_city=10, bound=(-100, 100), start_position=53514261
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_26\Mt19937.txt
# Run 9, Trial 26: num_city=10, bound=(-100, 100), start_position=41734620
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_27\Mt19937.txt
# Run 9, Trial 27: num_city=10, bound=(-100, 100), start_position=24618644
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_28\Mt19937.txt
# Run 9, Trial 28: num_city=10, bound=(-100, 100), start_position=19586847
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_29\Mt19937.txt
# Run 9, Trial 29: num_city=10, bound=(-100, 100), start_position=51806005
# Normalized sets saved to starting_solution\CEC2021\F92021\trial_30\Mt19937.txt
# Run 9, Trial 30: num_city=10, bound=(-100, 100), start_position=61394954
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_11\Mt19937.txt
# Run 10, Trial 11: num_city=10, bound=(-100, 100), start_position=77090257
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_12\Mt19937.txt
# Run 10, Trial 12: num_city=10, bound=(-100, 100), start_position=47537015
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_13\Mt19937.txt
# Run 10, Trial 13: num_city=10, bound=(-100, 100), start_position=30861148
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_14\Mt19937.txt
# Run 10, Trial 14: num_city=10, bound=(-100, 100), start_position=11098910
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_15\Mt19937.txt
# Run 10, Trial 15: num_city=10, bound=(-100, 100), start_position=14710053
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_16\Mt19937.txt
# Run 10, Trial 16: num_city=10, bound=(-100, 100), start_position=57486852
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_17\Mt19937.txt
# Run 10, Trial 17: num_city=10, bound=(-100, 100), start_position=33525865
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_18\Mt19937.txt
# Run 10, Trial 18: num_city=10, bound=(-100, 100), start_position=21708691
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_19\Mt19937.txt
# Run 10, Trial 19: num_city=10, bound=(-100, 100), start_position=7877778
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_20\Mt19937.txt
# Run 10, Trial 20: num_city=10, bound=(-100, 100), start_position=12834365
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_21\Mt19937.txt
# Run 10, Trial 21: num_city=10, bound=(-100, 100), start_position=4434326
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_22\Mt19937.txt
# Run 10, Trial 22: num_city=10, bound=(-100, 100), start_position=1651977
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_23\Mt19937.txt
# Run 10, Trial 23: num_city=10, bound=(-100, 100), start_position=4266727
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_24\Mt19937.txt
# Run 10, Trial 24: num_city=10, bound=(-100, 100), start_position=42034495
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_25\Mt19937.txt
# Run 10, Trial 25: num_city=10, bound=(-100, 100), start_position=15848223
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_26\Mt19937.txt
# Run 10, Trial 26: num_city=10, bound=(-100, 100), start_position=21976189
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_27\Mt19937.txt
# Run 10, Trial 27: num_city=10, bound=(-100, 100), start_position=61182254
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_28\Mt19937.txt
# Run 10, Trial 28: num_city=10, bound=(-100, 100), start_position=44550674
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_29\Mt19937.txt
# Run 10, Trial 29: num_city=10, bound=(-100, 100), start_position=6320027
# Normalized sets saved to starting_solution\CEC2021\F102021\trial_30\Mt19937.txt
# Run 10, Trial 30: num_city=10, bound=(-100, 100), start_position=61302462
